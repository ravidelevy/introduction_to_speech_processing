# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive')

# TODO: Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231/assignment1'
FOLDERNAME = 'Introduction to Speech Processing/'
assert FOLDERNAME is not None, "[!] Enter the folername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it
import sys
sys.path.append('/content/drive/MyDrive/{}'.format(FOLDERNAME))

# %cd /content/drive/MyDrive/$FOLDERNAME
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Introduction to Speech Processing

# %%
# !pip install jiwer
# !pip install tokenizers
# !pip install tensorboardX
# Out:
# Collecting jiwer
#   Downloading jiwer-3.0.2-py3-none-any.whl (21 kB)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from jiwer) (8.1.7)
# Collecting rapidfuzz==2.13.7 (from jiwer)
#   Downloading rapidfuzz-2.13.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 10.3 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, jiwer
# Successfully installed jiwer-3.0.2 rapidfuzz-2.13.7
# Collecting tokenizers
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 29.6 MB/s eta 0:00:00
# Installing collected packages: tokenizers
# Successfully installed tokenizers-0.13.3
# Collecting tensorboardX
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (1.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (23.1)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (3.20.3)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.6.2.2

# %%
import os

import torch
import random
import torchaudio
import torch.nn as nn
import torch.optim as optim

from librosa import effects

from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from jiwer import wer, cer

from tokenizers import Tokenizer
from tokenizers.models import BPE
from tokenizers.trainers import BpeTrainer
from torchaudio.models.decoder import ctc_decoder
from tokenizers.pre_tokenizers import Whitespace

from collections import defaultdict
from tensorboardX import SummaryWriter

VOCAB_SIZE = 198
# Out:
# /usr/local/lib/python3.10/dist-packages/torchaudio/models/decoder/_ctc_decoder.py:62: UserWarning: The built-in flashlight integration is deprecated, and will be removed in future release. Please install flashlight-text. https://pypi.org/project/flashlight-text/ For the detail of CTC decoder migration, please see https://github.com/pytorch/audio/issues/3088.
#   warnings.warn(

# %%
class AudioTranscriptDataset(Dataset):
    """ Custom dataset to zip audio files and their matching transcripts """

    def __init__(self, audio_folder, transcript_folder, audio_extension=".wav", transcript_extension=".txt"):
        self.audio_folder = audio_folder
        self.transcript_folder = transcript_folder
        self.audio_extension = audio_extension
        self.transcript_extension = transcript_extension
        self.audio_files = os.listdir(audio_folder)

    def __len__(self):
        return len(self.audio_files)

    def __getitem__(self, idx):
        audio_file = os.path.join(self.audio_folder, self.audio_files[idx])
        transcript_file = os.path.join(self.transcript_folder,
                                       self.audio_files[idx].replace(self.audio_extension, self.transcript_extension))
        waveform, sample_rate = torchaudio.load(audio_file)
        with open(transcript_file, "r") as f:
            transcript = f.read().strip()

        return waveform, transcript

# %%
class TextTransform:
    """Maps characters to integers and vice versa"""

    def __init__(self):
        # Initialize the tokenizer
        self.tokenizer = Tokenizer.from_file(rf"./tokenizer-train_{VOCAB_SIZE}.json")

    def text_to_int(self, text):
        """ Use a character map and convert text to an integer sequence """
        text = text.replace(" ", "[SPACE]")
        return self.tokenizer.encode(text).ids

        int_sequence = []
        for c in text:
            if c == ' ':
                ch = self.tokenizer.token_to_id("[SPACE]")
            else:
                ch = self.tokenizer.token_to_id(c)
            int_sequence.append(ch)
        return int_sequence

    def int_to_text(self, labels):
        """ Use a character map and convert integer labels to an text sequence """
        string = []
        for i in labels:
            string.append(self.tokenizer.id_to_token(int(i)))
        return ''.join(string).replace('[SPACE]', ' ')

    def int_to_text_with_space(self, labels):
      """ Use a character map and convert integer labels to an text sequence """
      string = []
      for i in labels:
          string.append(self.tokenizer.id_to_token(int(i)))
          string.append(' ')
      return ''.join(string).replace('[SPACE]', ' ')


text_transform = TextTransform()

# %%
def GreedyDecoder(output, labels, label_lengths, blank_label=VOCAB_SIZE, collapse_repeated=True):
    arg_maxes = torch.argmax(output, dim=2)
    decodes = []
    targets = []
    for i, args in enumerate(arg_maxes):
        decode = []
        targets.append(text_transform.int_to_text(labels[i][:label_lengths[i]].tolist()))
        for j, index in enumerate(args):
            if index != blank_label:
                if collapse_repeated and j != 0 and index == args[j - 1]:
                    continue
                decode.append(index.item())
        decodes.append(text_transform.int_to_text(decode))
    return decodes, targets

# %%
# Define the CTC model
class CTCModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, num_layers=2, dropout=0.3, ckpt_path=None):
        super(CTCModel, self).__init__()
        self.rnn = nn.LSTM(input_dim, hidden_dim, num_layers=num_layers, dropout=dropout, bidirectional=True,
                           batch_first=True)
        self.linear = nn.Linear(hidden_dim * 2, output_dim)  # *2 for bidirectional
        self.softmax = nn.LogSoftmax(dim=-1)

        # Initilize model's weigths when a path is given
        if ckpt_path is not None:
            self.load_state_dict(torch.load(ckpt_path))

    def forward(self, x):
        rnn_out, _ = self.rnn(x)
        linear_out = self.linear(rnn_out)
        return self.softmax(linear_out)

# %%
# Define the dataset and data loader
def load_an4_dataset(mode='train'):
    # Load the AN4 dataset and adjust the path accordingly
    audio_folder = f"./an4/{mode}/an4/wav/"
    transcript_folder = f"./an4/{mode}/an4/txt/"
    dataset = AudioTranscriptDataset(audio_folder, transcript_folder)

    return dataset


# MFCC feature extraction
# copied from fairseq/examples/hubert/simple_kmeans/dump_mfcc_feature.py on github
def get_feats(waveform):
    with torch.no_grad():
        x = waveform.float()
        x = x.view(1, -1)

        mfccs = torchaudio.compliance.kaldi.mfcc(
            waveform=x,
            sample_frequency=16000,
            use_energy=False,
        )  # (time, freq)
        mfccs = mfccs.transpose(0, 1)  # (freq, time)
        deltas = torchaudio.functional.compute_deltas(mfccs)
        ddeltas = torchaudio.functional.compute_deltas(deltas)
        concat = torch.cat([mfccs, deltas, ddeltas], dim=0)
        concat = concat.transpose(0, 1).contiguous()  # (freq, time)
        return concat


# Define the preprocessing function for MFCC feature extraction and target labels extraction
def data_processing(data, mode):
    mfccs = []
    labels = []
    input_lengths = []
    label_lengths = []
    for (waveform, transcript) in data:
        # Augment the waveform with probability
        if mode == 'train':
            waveform = augment_waveform(waveform)
        # Use 39 MFCC coefficients
        mfcc = get_feats(waveform)
        mfccs.append(mfcc)
        label = torch.Tensor(text_transform.text_to_int(transcript))
        labels.append(label)
        input_lengths.append(mfcc.shape[0])
        label_lengths.append(len(label))

    mfccs = nn.utils.rnn.pad_sequence(mfccs, batch_first=True)
    labels = nn.utils.rnn.pad_sequence(labels, batch_first=True, padding_value=1)
    return mfccs, labels, torch.tensor([mfccs.shape[1]] * mfccs.shape[0]), torch.tensor(
        [labels.shape[1]] * labels.shape[0])  # input_lengths, label_lengths


def augment_waveform(waveform, augmentation_probability=0.7):
    """
    Augment a waveform by adding random noise with the given probability.
    """
    noise_level = 0.02
    minimum_stretch_rate = 0.8
    stretch_factor = 0.4
    sample_rate = 16000
    num_semitones = 2
    min_factor = 1.0
    max_factor = 1.2

    waveform = waveform.numpy()
    probability = torch.rand(1)

    add_white_noise = lambda waveform: waveform + torch.randn_like(torch.tensor(waveform)).numpy() * noise_level
    time_stretch = lambda waveform: effects.time_stretch(waveform, rate=minimum_stretch_rate + stretch_factor * torch.rand(1).item())
    pitch_scale = lambda waveform: effects.pitch_shift(waveform, sr=sample_rate, n_steps=num_semitones)
    random_gain = lambda waveform: waveform * random.uniform(min_factor, max_factor)
    invert_polarity = lambda waveform: waveform * -1

    functions = [add_white_noise, time_stretch, pitch_scale, random_gain, invert_polarity]
    if probability < augmentation_probability:
      waveform = functions[int(probability * 5 / augmentation_probability)](waveform)

    return torch.tensor(waveform)

# %%
# Training function
def train(model, batch_size, print_interval, save_ckpt_interval, criterion, optimizer, device):
    # Load the AN4 train dataset
    train_dataset = load_an4_dataset(mode='train')

    # Preprocess the dataset and create the data loader
    data_loader = DataLoader(dataset=train_dataset,
                             batch_size=batch_size,
                             shuffle=True,
                             collate_fn=lambda x: data_processing(x, mode='train'))
    model.train()
    total_loss = 0.0

    for batch_idx, _data in enumerate(data_loader):
        batch_inputs, targets, input_lengths, target_lengths = _data
        batch_inputs, targets = batch_inputs.to(device), targets.to(device)
        optimizer.zero_grad()

        # Get model predictions
        outputs = model(batch_inputs).transpose(0, 1)

        # Calculate the CTC loss
        loss = criterion(outputs, targets, input_lengths, target_lengths)

        # Backpropagation and optimization step
        loss.backward()
        optimizer.step()

        # Print current batch loss
        if batch_idx % print_interval == 0:
            print(f"Batch {batch_idx}, Loss: {loss:.4f}")

        # Save the trained model
        # if batch_idx % save_ckpt_interval == 1:
        #   torch.save(model.state_dict(), "ctc_model.pt")

        total_loss += loss.item()

    return total_loss / len(data_loader)

# %%
def test(model, device, batch_size, criterion, mode='test', std_output=False):
    # Load the AN4 test dataset
    test_dataset = load_an4_dataset(mode=mode)

    # Preprocess the dataset and create the data loader
    test_loader = DataLoader(dataset=test_dataset,
                             batch_size=batch_size,
                             shuffle=False,
                             collate_fn=lambda x: data_processing(x, mode='test'))

    if std_output:
      print('\nevaluating...')
    model.eval()
    test_loss = 0
    test_cer, test_wer = [], []
    with torch.no_grad():
        for i, _data in enumerate(test_loader):
            mfccs, labels, input_lengths, label_lengths = _data
            mfccs, labels = mfccs.to(device), labels.to(device)

            output = model(mfccs)  # (batch, time, n_class)
            output = output.transpose(0, 1)  # (time, batch, n_class)

            loss = criterion(output, labels, input_lengths, label_lengths)
            test_loss += loss.item() / len(test_loader)

            # decoded_preds = tokenizer.decode_batch(torch.argmax(output.transpose(0, 1), dim=2).tolist())
            # labels = labels.tolist()
            # labels = [list(map(int, label.tolist())) for label in labels]
            # decoded_targets = tokenizer.decode_batch(labels)

            decoded_preds, decoded_targets = GreedyDecoder(output.transpose(0, 1), labels, label_lengths)

            for j in range(len(decoded_preds)):
                if std_output:
                  print("Target: " + decoded_targets[j])
                  print("Predicted: " + decoded_preds[j])
                test_cer.append(cer(decoded_targets[j], decoded_preds[j]))
                test_wer.append(wer(decoded_targets[j], decoded_preds[j]))

    avg_cer = sum(test_cer) / len(test_cer)
    avg_wer = sum(test_wer) / len(test_wer)

    if std_output:
      print('Test set: Average loss: {:.4f}, Average CER: {:4f}% Average WER: {:.4f}%\n'.format(test_loss, avg_cer * 100,
                                                                                                avg_wer * 100))
    return avg_cer, avg_wer, test_loss

# %%
def generate_lexicon():
    # tokenizer = text_transform.tokenizer
    dataset = load_an4_dataset(mode='train')
    lexicon = defaultdict(list)

    for example in dataset:
        words = example[1].split()  # Split transcription into words

        for word in words:
            tokens = text_transform.text_to_int(word)
            sub_words = text_transform.int_to_text_with_space(tokens)
            if sub_words+"|" not in lexicon[word]:
              lexicon[word].append(sub_words+ "|")

    # Save the lexicon to a file
    lexicon_path = "lexicon.txt"
    with open(lexicon_path, 'w') as f:
        for word, tokens_list in lexicon.items():
            f.write(f"{word} {' '.join(tokens_list)}\n")

    print("Lexicon generated and saved to", lexicon_path)

# %%
def loss_on_training_and_val_graph(input_dim, hidden_dim, output_dim, batch_size, print_interval,
                                   save_ckpt_interval, learning_rate, regularization, device):
    # Initialize SummaryWriter
    log_dir = "logs_loss_all"  # Directory to store the logs
    writer = SummaryWriter(log_dir=log_dir)

    # Initialize ASR model with the current hidden_dim
    model = CTCModel(input_dim, hidden_dim, output_dim).to(device)

    # Loss function and optimizer
    criterion = CTCLoss(device)
    optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=regularization)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=80, gamma=0.1)

    num_epochs = 120
    for epoch in range(num_epochs):

        avg_loss = train(model, batch_size, print_interval, save_ckpt_interval, criterion, optimizer, device)
        print(f"Epoch {epoch + 1}/{num_epochs}, Average Loss: {avg_loss:.4f} Hidden Dim: {hidden_dim}")
        scheduler.step()

        if epoch % 5 == 0:

          train_CER, train_WER, train_set_loss = test(model, device, batch_size, criterion, 'train', std_output=False)
          writer.add_scalars('Training Set Loss', {f'hidden_dim_{hidden_dim}':avg_loss}, epoch)
          writer.add_scalars('Training Set CER %', {f'hidden_dim_{hidden_dim}':train_CER}, epoch)
          writer.add_scalars('Training Set WER %', {f'hidden_dim_{hidden_dim}':train_WER}, epoch)

          val_CER, val_WER, val_set_loss = test(model, device, batch_size, criterion, 'val', std_output=False)
          writer.add_scalars('Validation Set Loss', {f'hidden_dim_{hidden_dim}':val_set_loss}, epoch)
          writer.add_scalars('Validation Set CER %', {f'hidden_dim_{hidden_dim}':val_CER}, epoch)
          writer.add_scalars('Validation Set WER %', {f'hidden_dim_{hidden_dim}':val_WER}, epoch)

          test_CER, test_WER, test_set_loss = test(model, device, batch_size, criterion, 'test', std_output=False)
          writer.add_scalars('test Set Loss', {f'hidden_dim_{hidden_dim}':test_set_loss}, epoch)
          writer.add_scalars('test Set CER %', {f'hidden_dim_{hidden_dim}':test_CER}, epoch)
          writer.add_scalars('test Set WER %', {f'hidden_dim_{hidden_dim}':test_WER}, epoch)

    # Close the SummaryWriter
    writer.close()
    return model

# %%
# CTC loss function
class CTCLoss(nn.Module):
    def __init__(self, device):
        super(CTCLoss, self).__init__()
        self.ctc_loss = nn.CTCLoss(blank=VOCAB_SIZE).to(device)

    def forward(self, log_probs, targets, input_lengths, target_lengths):
        return self.ctc_loss(log_probs, targets, input_lengths, target_lengths)

# %%
# Hyperparameters
input_dim = 39
hidden_dim = 1024
output_dim = VOCAB_SIZE + 1  # Number of characters in AN4 dataset, including blank (249)

batch_size = 16
print_interval = 15
save_ckpt_interval = 45
learning_rate = 0.0005
regularization = 0.001
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
criterion = CTCLoss(device)

model = loss_on_training_and_val_graph(input_dim, hidden_dim, output_dim, batch_size, print_interval,
                                       save_ckpt_interval, learning_rate, regularization, device)
# save final weights
torch.save(model.state_dict(), "./aug_sub_token_ctc_lstm_model.pt")
# Out:
# Batch 0, Loss: 85.2661
# Batch 15, Loss: 2.7895
# Batch 30, Loss: 2.5311
# Batch 45, Loss: 2.3734
# Epoch 1/120, Average Loss: 8.1826 Hidden Dim: 1024
# Batch 0, Loss: 1.3357
# Batch 15, Loss: 1.5120
# Batch 30, Loss: 1.5352
# Batch 45, Loss: 1.8268
# Epoch 2/120, Average Loss: 1.7225 Hidden Dim: 1024
# Batch 0, Loss: 1.6629
# Batch 15, Loss: 1.6920
# Batch 30, Loss: 1.8105
# Batch 45, Loss: 1.4948
# Epoch 3/120, Average Loss: 1.6843 Hidden Dim: 1024
# Batch 0, Loss: 1.5684
# Batch 15, Loss: 1.3562
# Batch 30, Loss: 1.5358
# Batch 45, Loss: 1.4720
# Epoch 4/120, Average Loss: 1.6449 Hidden Dim: 1024
# Batch 0, Loss: 1.2783
# Batch 15, Loss: 1.6791
# Batch 30, Loss: 1.5601
# Batch 45, Loss: 1.4503
# Epoch 5/120, Average Loss: 1.6413 Hidden Dim: 1024
# Batch 0, Loss: 1.7202
# Batch 15, Loss: 1.6543
# Batch 30, Loss: 1.3478
# Batch 45, Loss: 1.3147
# Epoch 6/120, Average Loss: 1.6049 Hidden Dim: 1024
# Batch 0, Loss: 2.2184
# Batch 15, Loss: 1.3027
# Batch 30, Loss: 1.7502
# Batch 45, Loss: 1.7166
# Epoch 7/120, Average Loss: 1.6181 Hidden Dim: 1024
# Batch 0, Loss: 1.6238
# Batch 15, Loss: 1.1318
# Batch 30, Loss: 1.3021
# Batch 45, Loss: 1.7827
# Epoch 8/120, Average Loss: 1.5422 Hidden Dim: 1024
# Batch 0, Loss: 1.5837
# Batch 15, Loss: 1.4638
# Batch 30, Loss: 1.7454
# Batch 45, Loss: 1.3056
# Epoch 9/120, Average Loss: 1.5133 Hidden Dim: 1024
# Batch 0, Loss: 1.3328
# Batch 15, Loss: 1.2574
# Batch 30, Loss: 1.1607
# Batch 45, Loss: 1.3460
# Epoch 10/120, Average Loss: 1.4350 Hidden Dim: 1024
# Batch 0, Loss: 1.2649
# Batch 15, Loss: 1.4108
# Batch 30, Loss: 1.4926
# Batch 45, Loss: 1.5239
# Epoch 11/120, Average Loss: 1.4408 Hidden Dim: 1024
# Batch 0, Loss: 1.6522
# Batch 15, Loss: 1.6013
# Batch 30, Loss: 1.2675
# Batch 45, Loss: 0.9638
# Epoch 12/120, Average Loss: 1.3769 Hidden Dim: 1024
# Batch 0, Loss: 0.9820
# Batch 15, Loss: 1.2802
# Batch 30, Loss: 1.2984
# Batch 45, Loss: 1.7913
# Epoch 13/120, Average Loss: 1.2813 Hidden Dim: 1024
# Batch 0, Loss: 1.2298
# Batch 15, Loss: 1.2650
# Batch 30, Loss: 1.2725
# Batch 45, Loss: 1.1576
# Epoch 14/120, Average Loss: 1.1995 Hidden Dim: 1024
# Batch 0, Loss: 1.2011
# Batch 15, Loss: 1.4404
# Batch 30, Loss: 1.0713
# Batch 45, Loss: 1.1046
# Epoch 15/120, Average Loss: 1.1156 Hidden Dim: 1024
# Batch 0, Loss: 0.9577
# Batch 15, Loss: 0.8696
# Batch 30, Loss: 1.2661
# Batch 45, Loss: 1.1682
# Epoch 16/120, Average Loss: 1.1196 Hidden Dim: 1024
# Batch 0, Loss: 1.3118
# Batch 15, Loss: 1.0906
# Batch 30, Loss: 1.1589
# Batch 45, Loss: 1.0018
# Epoch 17/120, Average Loss: 1.0108 Hidden Dim: 1024
# Batch 0, Loss: 0.7646
# Batch 15, Loss: 0.9877
# Batch 30, Loss: 1.0072
# Batch 45, Loss: 1.0417
# Epoch 18/120, Average Loss: 0.9673 Hidden Dim: 1024
# Batch 0, Loss: 0.8806
# Batch 15, Loss: 0.7447
# Batch 30, Loss: 1.4487
# Batch 45, Loss: 1.0507
# Epoch 19/120, Average Loss: 0.9794 Hidden Dim: 1024
# Batch 0, Loss: 0.8773
# Batch 15, Loss: 0.8849
# Batch 30, Loss: 0.9821
# Batch 45, Loss: 0.9696
# Epoch 20/120, Average Loss: 0.8966 Hidden Dim: 1024
# Batch 0, Loss: 0.7120
# Batch 15, Loss: 1.1809
# Batch 30, Loss: 0.4976
# Batch 45, Loss: 0.8416
# Epoch 21/120, Average Loss: 0.8433 Hidden Dim: 1024
# Batch 0, Loss: 1.1074
# Batch 15, Loss: 0.8642
# Batch 30, Loss: 1.0286
# Batch 45, Loss: 0.5932
# Epoch 22/120, Average Loss: 0.7759 Hidden Dim: 1024
# Batch 0, Loss: 0.6901
# Batch 15, Loss: 0.5445
# Batch 30, Loss: 0.6845
# Batch 45, Loss: 0.7652
# Epoch 23/120, Average Loss: 0.6579 Hidden Dim: 1024
# Batch 0, Loss: 0.4067
# Batch 15, Loss: 0.8816
# Batch 30, Loss: 0.5188
# Batch 45, Loss: 0.5369
# Epoch 24/120, Average Loss: 0.6148 Hidden Dim: 1024
# Batch 0, Loss: 0.6029
# Batch 15, Loss: 0.5023
# Batch 30, Loss: 0.4546
# Batch 45, Loss: 0.8144
# Epoch 25/120, Average Loss: 0.5457 Hidden Dim: 1024
# Batch 0, Loss: 0.5066
# Batch 15, Loss: 0.5087
# Batch 30, Loss: 0.6565
# Batch 45, Loss: 0.4798
# Epoch 26/120, Average Loss: 0.5640 Hidden Dim: 1024
# Batch 0, Loss: 0.5472
# Batch 15, Loss: 0.4696
# Batch 30, Loss: 0.5408
# Batch 45, Loss: 0.4585
# Epoch 27/120, Average Loss: 0.4960 Hidden Dim: 1024
# Batch 0, Loss: 0.6737
# Batch 15, Loss: 0.4408
# Batch 30, Loss: 0.3492
# Batch 45, Loss: 0.5906
# Epoch 28/120, Average Loss: 0.4595 Hidden Dim: 1024
# Batch 0, Loss: 0.4466
# Batch 15, Loss: 0.4004
# Batch 30, Loss: 0.5260
# Batch 45, Loss: 0.5195
# Epoch 29/120, Average Loss: 0.4495 Hidden Dim: 1024
# Batch 0, Loss: 0.4185
# Batch 15, Loss: 0.5637
# Batch 30, Loss: 0.3680
# Batch 45, Loss: 0.2660
# Epoch 30/120, Average Loss: 0.4203 Hidden Dim: 1024
# Batch 0, Loss: 0.3371
# Batch 15, Loss: 0.3879
# Batch 30, Loss: 0.3818
# Batch 45, Loss: 0.2573
# Epoch 31/120, Average Loss: 0.4052 Hidden Dim: 1024
# Batch 0, Loss: 0.4457
# Batch 15, Loss: 0.3708
# Batch 30, Loss: 0.3452
# Batch 45, Loss: 0.3564
# Epoch 32/120, Average Loss: 0.4144 Hidden Dim: 1024
# Batch 0, Loss: 0.5757
# Batch 15, Loss: 0.3222
# Batch 30, Loss: 0.4113
# Batch 45, Loss: 0.2689
# Epoch 33/120, Average Loss: 0.3812 Hidden Dim: 1024
# Batch 0, Loss: 0.3691
# Batch 15, Loss: 0.3311
# Batch 30, Loss: 0.2875
# Batch 45, Loss: 0.5910
# Epoch 34/120, Average Loss: 0.3941 Hidden Dim: 1024
# Batch 0, Loss: 0.4137
# Batch 15, Loss: 0.3058
# Batch 30, Loss: 0.3533
# Batch 45, Loss: 0.4996
# Epoch 35/120, Average Loss: 0.3950 Hidden Dim: 1024
# Batch 0, Loss: 0.3949
# Batch 15, Loss: 0.2904
# Batch 30, Loss: 0.3630
# Batch 45, Loss: 0.3832
# Epoch 36/120, Average Loss: 0.3829 Hidden Dim: 1024
# Batch 0, Loss: 0.4017
# Batch 15, Loss: 0.2994
# Batch 30, Loss: 0.2477
# Batch 45, Loss: 0.4498
# Epoch 37/120, Average Loss: 0.3904 Hidden Dim: 1024
# Batch 0, Loss: 0.4407
# Batch 15, Loss: 0.2839
# Batch 30, Loss: 0.3202
# Batch 45, Loss: 0.5591
# Epoch 38/120, Average Loss: 0.3913 Hidden Dim: 1024
# Batch 0, Loss: 0.3686
# Batch 15, Loss: 0.4410
# Batch 30, Loss: 0.3988
# Batch 45, Loss: 0.4592
# Epoch 39/120, Average Loss: 0.3651 Hidden Dim: 1024
# Batch 0, Loss: 0.2117
# Batch 15, Loss: 0.4057
# Batch 30, Loss: 0.5438
# Batch 45, Loss: 0.3594
# Epoch 40/120, Average Loss: 0.3919 Hidden Dim: 1024
# Batch 0, Loss: 0.3348
# Batch 15, Loss: 0.7000
# Batch 30, Loss: 0.3129
# Batch 45, Loss: 0.3401
# Epoch 41/120, Average Loss: 0.3823 Hidden Dim: 1024
# Batch 0, Loss: 0.3371
# Batch 15, Loss: 0.3141
# Batch 30, Loss: 0.4032
# Batch 45, Loss: 0.3214
# Epoch 42/120, Average Loss: 0.3716 Hidden Dim: 1024
# Batch 0, Loss: 0.3224
# Batch 15, Loss: 0.4671
# Batch 30, Loss: 0.2463
# Batch 45, Loss: 0.1920
# Epoch 43/120, Average Loss: 0.3565 Hidden Dim: 1024
# Batch 0, Loss: 0.2478
# Batch 15, Loss: 0.4313
# Batch 30, Loss: 0.3394
# Batch 45, Loss: 0.5603
# Epoch 44/120, Average Loss: 0.3520 Hidden Dim: 1024
# Batch 0, Loss: 0.2956
# Batch 15, Loss: 0.4049
# Batch 30, Loss: 0.4125
# Batch 45, Loss: 0.4854
# Epoch 45/120, Average Loss: 0.3563 Hidden Dim: 1024
# Batch 0, Loss: 0.2671
# Batch 15, Loss: 0.5013
# Batch 30, Loss: 0.3898
# Batch 45, Loss: 0.4440
# Epoch 46/120, Average Loss: 0.3638 Hidden Dim: 1024
# Batch 0, Loss: 0.4048
# Batch 15, Loss: 0.2821
# Batch 30, Loss: 0.3214
# Batch 45, Loss: 0.3314
# Epoch 47/120, Average Loss: 0.3641 Hidden Dim: 1024
# Batch 0, Loss: 0.2597
# Batch 15, Loss: 0.3880
# Batch 30, Loss: 0.6699
# Batch 45, Loss: 0.3701
# Epoch 48/120, Average Loss: 0.3817 Hidden Dim: 1024
# Batch 0, Loss: 0.3389
# Batch 15, Loss: 0.2417
# Batch 30, Loss: 0.2782
# Batch 45, Loss: 0.2530
# Epoch 49/120, Average Loss: 0.3320 Hidden Dim: 1024
# Batch 0, Loss: 0.2410
# Batch 15, Loss: 0.3177
# Batch 30, Loss: 0.3121
# Batch 45, Loss: 0.3190
# Epoch 50/120, Average Loss: 0.3529 Hidden Dim: 1024
# Batch 0, Loss: 0.2374
# Batch 15, Loss: 0.2241
# Batch 30, Loss: 0.2793
# Batch 45, Loss: 0.2513
# Epoch 51/120, Average Loss: 0.3143 Hidden Dim: 1024
# Batch 0, Loss: 0.3379
# Batch 15, Loss: 0.4559
# Batch 30, Loss: 0.2457
# Batch 45, Loss: 0.5310
# Epoch 52/120, Average Loss: 0.3399 Hidden Dim: 1024
# Batch 0, Loss: 0.2402
# Batch 15, Loss: 0.2351
# Batch 30, Loss: 0.3360
# Batch 45, Loss: 0.4949
# Epoch 53/120, Average Loss: 0.3145 Hidden Dim: 1024
# Batch 0, Loss: 0.2420
# Batch 15, Loss: 0.3274
# Batch 30, Loss: 0.2183
# Batch 45, Loss: 0.3887
# Epoch 54/120, Average Loss: 0.3198 Hidden Dim: 1024
# Batch 0, Loss: 0.2007
# Batch 15, Loss: 0.2751
# Batch 30, Loss: 0.1742
# Batch 45, Loss: 0.3329
# Epoch 55/120, Average Loss: 0.3162 Hidden Dim: 1024
# Batch 0, Loss: 0.2417
# Batch 15, Loss: 0.3557
# Batch 30, Loss: 0.2994
# Batch 45, Loss: 0.2321
# Epoch 56/120, Average Loss: 0.3332 Hidden Dim: 1024
# Batch 0, Loss: 0.2871
# Batch 15, Loss: 0.4321
# Batch 30, Loss: 0.5917
# Batch 45, Loss: 0.4941
# Epoch 57/120, Average Loss: 0.3734 Hidden Dim: 1024
# Batch 0, Loss: 0.3913
# Batch 15, Loss: 0.3400
# Batch 30, Loss: 0.2124
# Batch 45, Loss: 0.4063
# Epoch 58/120, Average Loss: 0.3353 Hidden Dim: 1024
# Batch 0, Loss: 0.2198
# Batch 15, Loss: 0.2645
# Batch 30, Loss: 0.3804
# Batch 45, Loss: 0.2131
# Epoch 59/120, Average Loss: 0.3454 Hidden Dim: 1024
# Batch 0, Loss: 0.5091
# Batch 15, Loss: 0.2740
# Batch 30, Loss: 0.2755
# Batch 45, Loss: 0.2913
# Epoch 60/120, Average Loss: 0.3302 Hidden Dim: 1024
# Batch 0, Loss: 0.2015
# Batch 15, Loss: 0.1829
# Batch 30, Loss: 0.4326
# Batch 45, Loss: 0.2109
# Epoch 61/120, Average Loss: 0.2923 Hidden Dim: 1024
# Batch 0, Loss: 0.2563
# Batch 15, Loss: 0.2270
# Batch 30, Loss: 0.4562
# Batch 45, Loss: 0.3558
# Epoch 62/120, Average Loss: 0.3025 Hidden Dim: 1024
# Batch 0, Loss: 0.5124
# Batch 15, Loss: 0.4618
# Batch 30, Loss: 0.4847
# Batch 45, Loss: 0.3063
# Epoch 63/120, Average Loss: 0.3621 Hidden Dim: 1024
# Batch 0, Loss: 0.2553
# Batch 15, Loss: 0.3209
# Batch 30, Loss: 0.3396
# Batch 45, Loss: 0.2200
# Epoch 64/120, Average Loss: 0.3361 Hidden Dim: 1024
# Batch 0, Loss: 0.2933
# Batch 15, Loss: 0.3178
# Batch 30, Loss: 0.2198
# Batch 45, Loss: 0.5046
# Epoch 65/120, Average Loss: 0.3101 Hidden Dim: 1024
# Batch 0, Loss: 0.2466
# Batch 15, Loss: 0.7989
# Batch 30, Loss: 0.2575
# Batch 45, Loss: 0.3262
# Epoch 66/120, Average Loss: 0.3274 Hidden Dim: 1024
# Batch 0, Loss: 0.2991
# Batch 15, Loss: 0.4668
# Batch 30, Loss: 0.4337
# Batch 45, Loss: 0.3141
# Epoch 67/120, Average Loss: 0.3264 Hidden Dim: 1024
# Batch 0, Loss: 0.4301
# Batch 15, Loss: 0.3748
# Batch 30, Loss: 0.2848
# Batch 45, Loss: 0.2281
# Epoch 68/120, Average Loss: 0.3400 Hidden Dim: 1024
# Batch 0, Loss: 0.2823
# Batch 15, Loss: 0.3608
# Batch 30, Loss: 0.3782
# Batch 45, Loss: 0.5737
# Epoch 69/120, Average Loss: 0.3470 Hidden Dim: 1024
# Batch 0, Loss: 0.4226
# Batch 15, Loss: 0.2804
# Batch 30, Loss: 0.2407
# Batch 45, Loss: 0.4638
# Epoch 70/120, Average Loss: 0.3540 Hidden Dim: 1024
# Batch 0, Loss: 0.2664
# Batch 15, Loss: 0.2751
# Batch 30, Loss: 0.2480
# Batch 45, Loss: 0.2622
# Epoch 71/120, Average Loss: 0.2733 Hidden Dim: 1024
# Batch 0, Loss: 0.2583
# Batch 15, Loss: 0.2784
# Batch 30, Loss: 0.2339
# Batch 45, Loss: 0.2538
# Epoch 72/120, Average Loss: 0.3041 Hidden Dim: 1024
# Batch 0, Loss: 0.2217
# Batch 15, Loss: 0.2572
# Batch 30, Loss: 0.3438
# Batch 45, Loss: 0.2703
# Epoch 73/120, Average Loss: 0.2915 Hidden Dim: 1024
# Batch 0, Loss: 0.3526
# Batch 15, Loss: 0.3488
# Batch 30, Loss: 0.2150
# Batch 45, Loss: 0.2056
# Epoch 74/120, Average Loss: 0.3088 Hidden Dim: 1024
# Batch 0, Loss: 0.4292
# Batch 15, Loss: 0.2412
# Batch 30, Loss: 0.1657
# Batch 45, Loss: 0.2931
# Epoch 75/120, Average Loss: 0.3476 Hidden Dim: 1024
# Batch 0, Loss: 0.2543
# Batch 15, Loss: 0.2981
# Batch 30, Loss: 0.2664
# Batch 45, Loss: 0.3165
# Epoch 76/120, Average Loss: 0.3014 Hidden Dim: 1024
# Batch 0, Loss: 0.2578
# Batch 15, Loss: 0.2024
# Batch 30, Loss: 0.2316
# Batch 45, Loss: 0.2703
# Epoch 77/120, Average Loss: 0.2714 Hidden Dim: 1024
# Batch 0, Loss: 0.2054
# Batch 15, Loss: 0.2680
# Batch 30, Loss: 0.2896
# Batch 45, Loss: 0.2167
# Epoch 78/120, Average Loss: 0.2639 Hidden Dim: 1024
# Batch 0, Loss: 0.1641
# Batch 15, Loss: 0.1840
# Batch 30, Loss: 0.1966
# Batch 45, Loss: 0.2336
# Epoch 79/120, Average Loss: 0.2756 Hidden Dim: 1024
# Batch 0, Loss: 0.2478
# Batch 15, Loss: 0.3299
# Batch 30, Loss: 0.2523
# Batch 45, Loss: 0.3460
# Epoch 80/120, Average Loss: 0.2867 Hidden Dim: 1024
# Batch 0, Loss: 0.2785
# Batch 15, Loss: 0.1433
# Batch 30, Loss: 0.2785
# Batch 45, Loss: 0.1667
# Epoch 81/120, Average Loss: 0.2441 Hidden Dim: 1024
# Batch 0, Loss: 0.3021
# Batch 15, Loss: 0.1581
# Batch 30, Loss: 0.2212
# Batch 45, Loss: 0.2992
# Epoch 82/120, Average Loss: 0.2334 Hidden Dim: 1024
# Batch 0, Loss: 0.1747
# Batch 15, Loss: 0.2146
# Batch 30, Loss: 0.2156
# Batch 45, Loss: 0.1362
# Epoch 83/120, Average Loss: 0.2128 Hidden Dim: 1024
# Batch 0, Loss: 0.2152
# Batch 15, Loss: 0.1733
# Batch 30, Loss: 0.1990
# Batch 45, Loss: 0.1853
# Epoch 84/120, Average Loss: 0.2098 Hidden Dim: 1024
# Batch 0, Loss: 0.1999
# Batch 15, Loss: 0.1353
# Batch 30, Loss: 0.1733
# Batch 45, Loss: 0.1627
# Epoch 85/120, Average Loss: 0.1994 Hidden Dim: 1024
# Batch 0, Loss: 0.2255
# Batch 15, Loss: 0.2142
# Batch 30, Loss: 0.1761
# Batch 45, Loss: 0.2067
# Epoch 86/120, Average Loss: 0.2082 Hidden Dim: 1024
# Batch 0, Loss: 0.2453
# Batch 15, Loss: 0.1794
# Batch 30, Loss: 0.1454
# Batch 45, Loss: 0.2347
# Epoch 87/120, Average Loss: 0.2100 Hidden Dim: 1024
# Batch 0, Loss: 0.1339
# Batch 15, Loss: 0.1483
# Batch 30, Loss: 0.1516
# Batch 45, Loss: 0.1695
# Epoch 88/120, Average Loss: 0.1947 Hidden Dim: 1024
# Batch 0, Loss: 0.2527
# Batch 15, Loss: 0.1426
# Batch 30, Loss: 0.1498
# Batch 45, Loss: 0.2600
# Epoch 89/120, Average Loss: 0.1959 Hidden Dim: 1024
# Batch 0, Loss: 0.2440
# Batch 15, Loss: 0.1659
# Batch 30, Loss: 0.1733
# Batch 45, Loss: 0.1502
# Epoch 90/120, Average Loss: 0.1882 Hidden Dim: 1024
# Batch 0, Loss: 0.1535
# Batch 15, Loss: 0.1202
# Batch 30, Loss: 0.1810
# Batch 45, Loss: 0.2291
# Epoch 91/120, Average Loss: 0.1942 Hidden Dim: 1024
# Batch 0, Loss: 0.2064
# Batch 15, Loss: 0.2697
# Batch 30, Loss: 0.1548
# Batch 45, Loss: 0.1600
# Epoch 92/120, Average Loss: 0.2038 Hidden Dim: 1024
# Batch 0, Loss: 0.2642
# Batch 15, Loss: 0.2253
# Batch 30, Loss: 0.1386
# Batch 45, Loss: 0.2121
# Epoch 93/120, Average Loss: 0.1906 Hidden Dim: 1024
# Batch 0, Loss: 0.2288
# Batch 15, Loss: 0.2522
# Batch 30, Loss: 0.2057
# Batch 45, Loss: 0.1232
# Epoch 94/120, Average Loss: 0.2009 Hidden Dim: 1024
# Batch 0, Loss: 0.1678
# Batch 15, Loss: 0.1344
# Batch 30, Loss: 0.1459
# Batch 45, Loss: 0.1993
# Epoch 95/120, Average Loss: 0.1974 Hidden Dim: 1024
# Batch 0, Loss: 0.1651
# Batch 15, Loss: 0.1680
# Batch 30, Loss: 0.1805
# Batch 45, Loss: 0.1840
# Epoch 96/120, Average Loss: 0.1942 Hidden Dim: 1024
# Batch 0, Loss: 0.1396
# Batch 15, Loss: 0.2944
# Batch 30, Loss: 0.2765
# Batch 45, Loss: 0.1764
# Epoch 97/120, Average Loss: 0.1974 Hidden Dim: 1024
# Batch 0, Loss: 0.1581
# Batch 15, Loss: 0.3352
# Batch 30, Loss: 0.2387
# Batch 45, Loss: 0.1404
# Epoch 98/120, Average Loss: 0.1970 Hidden Dim: 1024
# Batch 0, Loss: 0.1284
# Batch 15, Loss: 0.1834
# Batch 30, Loss: 0.1474
# Batch 45, Loss: 0.1469
# Epoch 99/120, Average Loss: 0.2002 Hidden Dim: 1024
# Batch 0, Loss: 0.1733
# Batch 15, Loss: 0.1755
# Batch 30, Loss: 0.1798
# Batch 45, Loss: 0.4277
# Epoch 100/120, Average Loss: 0.1953 Hidden Dim: 1024
# Batch 0, Loss: 0.2146
# Batch 15, Loss: 0.1475
# Batch 30, Loss: 0.2095
# Batch 45, Loss: 0.2943
# Epoch 101/120, Average Loss: 0.1861 Hidden Dim: 1024
# Batch 0, Loss: 0.1399
# Batch 15, Loss: 0.1342
# Batch 30, Loss: 0.1774
# Batch 45, Loss: 0.1435
# Epoch 102/120, Average Loss: 0.1778 Hidden Dim: 1024
# Batch 0, Loss: 0.2538
# Batch 15, Loss: 0.1353
# Batch 30, Loss: 0.1586
# Batch 45, Loss: 0.3220
# Epoch 103/120, Average Loss: 0.1923 Hidden Dim: 1024
# Batch 0, Loss: 0.1469
# Batch 15, Loss: 0.1437
# Batch 30, Loss: 0.1771
# Batch 45, Loss: 0.2029
# Epoch 104/120, Average Loss: 0.1894 Hidden Dim: 1024
# Batch 0, Loss: 0.2169
# Batch 15, Loss: 0.1893
# Batch 30, Loss: 0.2023
# Batch 45, Loss: 0.3376
# Epoch 105/120, Average Loss: 0.1940 Hidden Dim: 1024
# Batch 0, Loss: 0.2231
# Batch 15, Loss: 0.2047
# Batch 30, Loss: 0.2459
# Batch 45, Loss: 0.2489
# Epoch 106/120, Average Loss: 0.1937 Hidden Dim: 1024
# Batch 0, Loss: 0.1533
# Batch 15, Loss: 0.2116
# Batch 30, Loss: 0.1663
# Batch 45, Loss: 0.1930
# Epoch 107/120, Average Loss: 0.1903 Hidden Dim: 1024
# Batch 0, Loss: 0.1524
# Batch 15, Loss: 0.2078
# Batch 30, Loss: 0.1680
# Batch 45, Loss: 0.1584
# Epoch 108/120, Average Loss: 0.1848 Hidden Dim: 1024
# Batch 0, Loss: 0.2648
# Batch 15, Loss: 0.1293
# Batch 30, Loss: 0.2278
# Batch 45, Loss: 0.1881
# Epoch 109/120, Average Loss: 0.2079 Hidden Dim: 1024
# Batch 0, Loss: 0.1486
# Batch 15, Loss: 0.1127
# Batch 30, Loss: 0.1978
# Batch 45, Loss: 0.1788
# Epoch 110/120, Average Loss: 0.1845 Hidden Dim: 1024
# Batch 0, Loss: 0.2144
# Batch 15, Loss: 0.2040
# Batch 30, Loss: 0.1357
# Batch 45, Loss: 0.1412
# Epoch 111/120, Average Loss: 0.1774 Hidden Dim: 1024
# Batch 0, Loss: 0.1302
# Batch 15, Loss: 0.1684
# Batch 30, Loss: 0.1784
# Batch 45, Loss: 0.1788
# Epoch 112/120, Average Loss: 0.1862 Hidden Dim: 1024
# Batch 0, Loss: 0.1905
# Batch 15, Loss: 0.2087
# Batch 30, Loss: 0.1215
# Batch 45, Loss: 0.1531
# Epoch 113/120, Average Loss: 0.1905 Hidden Dim: 1024
# Batch 0, Loss: 0.1572
# Batch 15, Loss: 0.1554
# Batch 30, Loss: 0.1582
# Batch 45, Loss: 0.1692
# Epoch 114/120, Average Loss: 0.1940 Hidden Dim: 1024
# Batch 0, Loss: 0.1718
# Batch 15, Loss: 0.1916
# Batch 30, Loss: 0.2353
# Batch 45, Loss: 0.2160
# Epoch 115/120, Average Loss: 0.1926 Hidden Dim: 1024
# Batch 0, Loss: 0.1740
# Batch 15, Loss: 0.2630
# Batch 30, Loss: 0.1880
# Batch 45, Loss: 0.1720
# Epoch 116/120, Average Loss: 0.2164 Hidden Dim: 1024
# Batch 0, Loss: 0.2045
# Batch 15, Loss: 0.2945
# Batch 30, Loss: 0.2064
# Batch 45, Loss: 0.1353
# Epoch 117/120, Average Loss: 0.1989 Hidden Dim: 1024
# Batch 0, Loss: 0.1506
# Batch 15, Loss: 0.1614
# Batch 30, Loss: 0.1630
# Batch 45, Loss: 0.1969
# Epoch 118/120, Average Loss: 0.1946 Hidden Dim: 1024
# Batch 0, Loss: 0.2049
# Batch 15, Loss: 0.2092
# Batch 30, Loss: 0.1360
# Batch 45, Loss: 0.1303
# Epoch 119/120, Average Loss: 0.1883 Hidden Dim: 1024
# Batch 0, Loss: 0.2351
# Batch 15, Loss: 0.1385
# Batch 30, Loss: 0.1744
# Batch 45, Loss: 0.3798
# Epoch 120/120, Average Loss: 0.1894 Hidden Dim: 1024

# %%
model = CTCModel(input_dim, hidden_dim, output_dim, ckpt_path="./aug_sub_token_ctc_lstm_model.pt").to(device)
test(model, device, batch_size, criterion, mode='train', std_output=True)
# Out:
# evaluating...
# Target: HELP
# Predicted: HELP
# Target: FIVE TWO SEVEN
# Predicted: FIVE TWO SEVEN
# Target: O A K D A L E D R I V E
# Predicted: O A K D A L E D R I V E
# Target: NO
# Predicted: NO
# Target: ONE TWO FOUR ONE
# Predicted: ONE TWO FOUR ONE
# Target: M I C H A E L
# Predicted: M I C H A E L
# Target: B R O S T
# Predicted: B R O S T
# Target: RUBOUT F M Q N H THREE SEVENTY
# Predicted: RUBOUT F M Q N H THREE SEVENTY
# Target: GO
# Predicted: GO
# Target: ONE FIVE TWO ZERO SEVEN
# Predicted: ONE FIVE TWO ZERO SEVEN
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: L O O F B O U R R O W
# Predicted: L O O F B O U R R O W
# Target: T V A H FIFTY TWO FIFTY THREE
# Predicted: T V A H FIFTY TWO FIFTY THREE
# Target: H I N I C H
# Predicted: H I N I C H
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: SEVEN FOURTEEN SIXTY ONE
# Predicted: SEVEN FOURTEEN SIXTY ONE
# Target: FOUR ONE TWO EIGHT THREE ONE NINE FIVE ONE THREE
# Predicted: FOUR ONE TWO EIGHT THREE ONE NINE FIVE ONE THREE
# Target: H I G H L A N D
# Predicted: H I G H L A N D
# Target: REPEAT
# Predicted: REPEAT
# Target: ENTER FORTY THREE FORTY FIVE
# Predicted: ENTER FORTY THREE FORTY FIVE
# Target: EIGHT FORTY ONE
# Predicted: EIGHT FORTY ONE
# Target: TWO FIVE TWO TWO OH TWO NINE
# Predicted: TWO FIVE TWO TWO OH TWO NINE
# Target: L Z R V FIFTY FIVE THIRTY FIVE
# Predicted: L Z R V FIFTY FIVE THIRTY FIVE
# Target: SIX FOUR FIVE THREE THREE SIX FOUR
# Predicted: SIX FOUR FIVE THREE THREE SIX FOUR
# Target: START
# Predicted: START
# Target: S Z K W W TWO THIRTY SEVEN
# Predicted: S Z K W W TWO THIRTY SEVEN
# Target: STOP
# Predicted: STOP
# Target: ERASE V R F O FIVE
# Predicted: ERASE V R F O FIVE
# Target: TWENTY TWO TWENTY SIX
# Predicted: TWENTY TWO TWENTY SIX
# Target: FIVE SIX THREE ONE
# Predicted: FIVE SIX THREE ONE
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: SIX TWO FIVE ONE FIVE SIX FOUR
# Predicted: SIX TWO FIVE ONE FIVE SIX FOUR
# Target: SEVEN FIFTY FIVE
# Predicted: SEVEN FIFTY FIVE
# Target: G E E P C SEVEN ONE OH SEVEN
# Predicted: G E E P C SEVEN ONE OH SEVEN
# Target: NO
# Predicted: NO
# Target: RUBOUT P O O B EIGHT
# Predicted: RUBOUT P O O B EIGHT
# Target: NINE FOUR OH EIGHT SIX
# Predicted: NINE FOUR OH EIGHT SIX
# Target: S H E I L A
# Predicted: S H E I L A
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: YES
# Predicted: YES
# Target: ERASE X B M N T FOUR ONE OH NINE
# Predicted: ERASE X B M N T FOUR ONE OH NINE
# Target: SEVEN SEVENTEEN FIFTY SEVEN
# Predicted: SEVEN SEVENTEEN FIFTY SEVEN
# Target: STOP
# Predicted: STOP
# Target: SIX TWENTY SIX SIXTY THREE
# Predicted: SIX TWENTY SIX SIXTY THREE
# Target: RUBOUT R R N A A NINETY FOUR
# Predicted: RUBOUT R R N A A NINETY FOUR
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: T H A Y E R
# Predicted: T H A Y E R
# Target: ERASE Y B E J Q FIVE OH SEVEN
# Predicted: ERASE Y B E J Q FIVE OH SEVEN
# Target: G TWO EIGHTY NINE
# Predicted: G TWO EIGHTY NINE
# Target: ONE FIVE ONE ONE SIX
# Predicted: ONE FIVE ONE ONE SIX
# Target: NO
# Predicted: NO
# Target: G L E N N
# Predicted: G L E N N
# Target: M O H N K E R N
# Predicted: M O H N K E R N
# Target: ONE FIVE TWO THREE NINE
# Predicted: ONE FIVE TWO THREE NINE
# Target: P O M E R A N T Z
# Predicted: P O M E R A N T Z
# Target: A Y L E S B O R O
# Predicted: A Y L E S B O R O
# Target: ONE THOUSAND
# Predicted: ONE THOUSAND
# Target: M A R K
# Predicted: M A R K
# Target: ERASE A L H N C THIRTY FIVE
# Predicted: ERASE A L H N C THIRTY FIVE
# Target: H Z A E THREE SEVEN FIVE ONE
# Predicted: H Z A E THREE SEVEN FIVE ONE
# Target: C H A R L E S
# Predicted: C H A R L E S
# Target: THIRTY
# Predicted: THIRTY
# Target: SIX SIX ONE FIVE ZERO SIX FOUR
# Predicted: SIX SIX ONE FIVE ZERO SIX FOUR
# Target: R G C S SEVEN SIXTY SEVEN
# Predicted: R G C S SEVEN SIXTY SEVEN
# Target: ENTER EIGHT TWO FOUR TWO
# Predicted: ENTER EIGHT TWO FOUR TWO
# Target: V Q D B FORTY NINE HUNDRED
# Predicted: V Q D B FORTY NINE HUNDRED
# Target: ONE FIVE TWO ONE THREE
# Predicted: ONE FIVE TWO ONE THREE
# Target: SIXTY SEVEN TEN
# Predicted: SIXTY SEVEN TEN
# Target: ENTER SEVEN
# Predicted: ENTER SEVEN
# Target: F E G B FORTY EIGHT
# Predicted: F E G B FORTY EIGHT
# Target: AUGUST SIXTEENTH NINETEEN SIXTY FIVE
# Predicted: AUGUST SIXTEEN NINETEEN SIXTY FIVE
# Target: YES
# Predicted: YES
# Target: TWELVE FOUR SIXTY SEVEN
# Predicted: TWELVE FOUR SIXTY SEVEN
# Target: N O O N B U R G
# Predicted: N O O N B U R G
# Target: OH SIX OH SEVEN SIX SIX
# Predicted: OH SIX OH SEVEN SIX SIX
# Target: FIVE TWENTY SIX FORTY FIVE
# Predicted: FIVE TWENTY SIX FORTY FIVE
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: S O U T H
# Predicted: S O U T H
# Target: Z C B E G SEVENTY NINE
# Predicted: Z C B E G SEVENTY NINE
# Target: ONE TEN
# Predicted: ONE TEN
# Target: THREE ONE TWO
# Predicted: THREE ONE TWO
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: V A N D E R L A A N
# Predicted: V A N D E R L A A N
# Target: ONE ELEVEN
# Predicted: ONE ELEVEN
# Target: YES
# Predicted: YES
# Target: A G L G A SIX HUNDRED FORTY NINE
# Predicted: A G L G A SIX HUNDRED FORTY NINE
# Target: M O N I C A
# Predicted: M O N I C A
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: SEVEN MAY NINETEEN FORTY FOUR
# Predicted: SEVEN MAY NINETEEN FORTY FOUR
# Target: A L T M A N N
# Predicted: A L T M A N N
# Target: YES
# Predicted: YES
# Target: STOP
# Predicted: STOP
# Target: B E A C O N
# Predicted: B E A C O N
# Target: RUBOUT N A G K K THREE THIRTY SIX
# Predicted: RUBOUT N A G K K THREE THIRTY SIX
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: TEN TWELVE SIXTY SEVEN
# Predicted: TEN TWELVE SIXTY SEVEN
# Target: B O U Q U E T
# Predicted: B O U Q U E T
# Target: NINE THREE FIVE OH SIX NINE TWO
# Predicted: NINE THREE FIVE OH SIX NINE TWO
# Target: ONE OH TWO
# Predicted: ONE OH TWO
# Target: Y W A A M TWO
# Predicted: Y W A A M TWO
# Target: ONE ZERO SIX FIVE
# Predicted: ONE ZERO SIX FIVE
# Target: J E N N I F E R
# Predicted: J E N N I F E R
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: C E N T R E A V E
# Predicted: C E N T R E A V E
# Target: SEVEN THIRTY
# Predicted: SEVEN THIRTY
# Target: TWO SEVEN NINE TWO THREE TWO FOUR
# Predicted: TWO SEVEN NINE TWO THREE TWO FOUR
# Target: ONE FIVE TWO THREE TWO
# Predicted: ONE FIVE TWO THREE TWO
# Target: ENTER SIX TWO FOUR
# Predicted: ENTER SIX TWO FOUR
# Target: L I N D A
# Predicted: L I N D A
# Target: FOUR TWENTY EIGHT SEVENTY ONE
# Predicted: FOUR TWENTY EIGHT SEVENTY ONE
# Target: SEPTEMBER FIFTEENTH NINETEEN SIXTY FIVE
# Predicted: SEPTEMBER FIFTEENTH NINETEEN SIXTY FIVE
# Target: ONE FIVE TWO TWO ONE
# Predicted: ONE FIVE TWO TWO ONE
# Target: ENTER FOURTEEN
# Predicted: ENTER FOURTEEN
# Target: P U X P I FIVE
# Predicted: P U X P I FIVE
# Target: ONE FIVE TWO TWO ONE
# Predicted: ONE FIVE TWO TWO ONE
# Target: ENTER SIX ONE TWO FIVE
# Predicted: ENTER SIX ONE TWO FIVE
# Target: K E A N E
# Predicted: K E A N E
# Target: SEVEN THREE ONE ONE THREE THREE EIGHT
# Predicted: SEVEN THREE ONE ONE THREE THREE EIGHT
# Target: YES
# Predicted: YES
# Target: NINE THIRTY SIXTY FIVE
# Predicted: NINE THIRTY SIXTY FIVE
# Target: RUBOUT J L Y Z TWO
# Predicted: RUBOUT J L Y Z TWO
# Target: SEVEN TWENTY NINE FIFTY EIGHT
# Predicted: SEVEN TWENTY NINE FIFTY EIGHT
# Target: ERASE Z Y G N P EIGHT HUNDRED AND TWENTY THREE
# Predicted: ERASE Z Y G N P EIGHT HUNDRED AND TWENTY THREE
# Target: SEPTEMBER TWENTY SEVENTH NINETEEN SIXTY SEVEN
# Predicted: SEPTEMBER TWENTY SEVENTH NINETEEN SIXTY SEVEN
# Target: ENTER FIFTY SIXTY THREE
# Predicted: ENTER FIFTY SIXTY THREE
# Target: S N O W
# Predicted: S N O W
# Target: S T E V E
# Predicted: S T E V E
# Target: FIFTY EIGHT OH NINE AND A HALF
# Predicted: FIFTY EIGHT OH NINE AND A HALF
# Target: ENTER FIVE ZERO
# Predicted: ENTER FIVE ZERO
# Target: M A T T H E W
# Predicted: M A T T H E W
# Target: ENTER ONE NINE
# Predicted: ENTER ONE NINE
# Target: ENTER EIGHT ONE NINE SIX
# Predicted: ENTER EIGHT ONE NINE SIX
# Target: FOUR OH THREE
# Predicted: FOUR OH THREE
# Target: B SEVEN TWENTY FIVE
# Predicted: B SEVEN TWENTY FIVE
# Target: E W A L D
# Predicted: E W A L D
# Target: ONE OH OH TWO EIGHT
# Predicted: ONE OH OH TWO EIGHT
# Target: STOP
# Predicted: STOP
# Target: C O N N E L L Y
# Predicted: C O N N E L L Y
# Target: E A S T E N D A V E
# Predicted: E A S T E N D A V E
# Target: TWO OH ONE FOUR SIX FOUR SIX OH EIGHT THREE
# Predicted: TWO OH ONE FOUR SIX FOUR SIX OH EIGHT THREE
# Target: S L E E P Y H O L L O W
# Predicted: S L E E P Y H O L L O W
# Target: L R R K I FOUR
# Predicted: L R R K I FOUR
# Target: ENTER TWO OH FIVE
# Predicted: ENTER TWO OH FIVE
# Target: P G H
# Predicted: P G H
# Target: FOUR TWO ONE OH FOUR FIVE ONE
# Predicted: FOUR TWO ONE OH FOUR FIVE ONE
# Target: OH SIX SEVEN OH EIGHT
# Predicted: OH SIX SEVEN OH EIGHT
# Target: YES
# Predicted: YES
# Target: ONE FIVE ONE FOUR SEVEN
# Predicted: ONE FIVE ONE FOUR SEVEN
# Target: ENTER SIXTY ONE
# Predicted: ENTER SIXTY ONE
# Target: S T O D O L S K Y
# Predicted: S T O D O L S K Y
# Target: ENTER FOUR
# Predicted: ENTER FOUR
# Target: ONE FIVE TWO TWO ONE
# Predicted: ONE FIVE TWO TWO ONE
# Target: S U O U EIGHTY SIX
# Predicted: S U O U EIGHTY SIX
# Target: RUBOUT U T D A TWO
# Predicted: RUBOUT U T D A TWO
# Target: RUBOUT G U K E V NINE
# Predicted: RUBOUT G U K E V NINE
# Target: ENTER SIX
# Predicted: ENTER SIX
# Target: B J X K TWENTY THREE
# Predicted: B J X K TWENTY THREE
# Target: T H A D
# Predicted: T H A D
# Target: STOP
# Predicted: STOP
# Target: B E C H T E L
# Predicted: B E C H T E L
# Target: ERASE G W D K F SIX EIGHTY EIGHT
# Predicted: ERASE G W D K F SIX EIGHTY EIGHT
# Target: L R L Y U SEVEN THREE
# Predicted: L R L Y U SEVEN THREE
# Target: THREE TWO SEVEN ONE SIX NINE FIVE
# Predicted: THREE TWO SEVEN ONE SIX NINE FIVE
# Target: B R E N N A N
# Predicted: B R E N N A N
# Target: MARCH THIRD NINETEEN TWENTY EIGHT
# Predicted: MARCH THIRD NINETEEN TWENTY EIGHT
# Target: SIX EIGHT THREE FIVE ZERO FOUR ONE
# Predicted: SIX EIGHT THREE FIVE ZERO FOUR ONE
# Target: STOP
# Predicted: STOP
# Target: M O R E W O O D
# Predicted: M O R E W O O D
# Target: ONE FIVE TWO ONE SEVEN
# Predicted: ONE FIVE TWO ONE SEVEN
# Target: N E G L E Y
# Predicted: N E G L E Y
# Target: W A Y N E
# Predicted: W A Y N E
# Target: ENTER NINETY FOUR
# Predicted: ENTER NINETY FOUR
# Target: P O U N B FIVE
# Predicted: P O U N B FIVE
# Target: RUBOUT Z G D R G NINE NINE FOUR SIX
# Predicted: RUBOUT Z G D R G NINE NINE FOUR SIX
# Target: ERASE J G Q Y EIGHT SIX ONE
# Predicted: ERASE J G Q Y EIGHT SIX ONE
# Target: ONE FIVE TWO THREE TWO
# Predicted: ONE FIVE TWO THREE TWO
# Target: ONE FIVE ONE FOUR SEVEN
# Predicted: ONE FIVE ONE FOUR SEVEN
# Target: ONE FIVE ONE THREE THREE
# Predicted: ONE FIVE ONE THREE THREE
# Target: J E A N E T T E
# Predicted: J E A N E T T E
# Target: C H R I S T O P H E R
# Predicted: C H R I S T O P H E R
# Target: D O W N I N G T O W N
# Predicted: D O W N I N G T O W N
# Target: ONE FIVE TWO TWO SEVEN
# Predicted: ONE FIVE TWO TWO SEVEN
# Target: ONE FIVE TWO TWO ONE
# Predicted: ONE FIVE TWO TWO ONE
# Target: FOUR ONE TWO FIVE TWO ONE FIVE THREE THREE NINE
# Predicted: FOUR ONE TWO FIVE TWO ONE FIVE THREE THREE NINE
# Target: C M U
# Predicted: C M U
# Target: Q C J K EIGHT FIVE EIGHT
# Predicted: Q C J K EIGHT FIVE EIGHT
# Target: YES
# Predicted: YES
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: REPEAT
# Predicted: REPEAT
# Target: ONE FIVE TWO ONE EIGHT
# Predicted: ONE FIVE TWO ONE EIGHT
# Target: NINE ONE FOUR THREE THREE SEVEN ONE EIGHT SIX NINE
# Predicted: NINE ONE FOUR THREE THREE SEVEN ONE EIGHT SIX NINE
# Target: ENTER THREE
# Predicted: ENTER THREE
# Target: HELP
# Predicted: HELP
# Target: ONE FIVE TWO OH SIX
# Predicted: ONE FIVE TWO OH SIX
# Target: B E A C O N
# Predicted: B E A C O N
# Target: H A H L E FOUR NINETY ONE
# Predicted: H A H L E FOUR NINETY ONE
# Target: SIX THREE EIGHT
# Predicted: SIX THREE EIGHT
# Target: G I B S O N I A
# Predicted: G I B S O N I A
# Target: RUBOUT C T L E SEVENTY SIX TWELVE
# Predicted: RUBOUT C T L E SEVENTY SIX TWELVE
# Target: ONE FIVE TWO ONE SEVEN
# Predicted: ONE FIVE TWO ONE SEVEN
# Target: M A R G A R E T
# Predicted: M A R G A R E T
# Target: TWO SIX EIGHT THREE ZERO SIX SIX
# Predicted: TWO SIX EIGHT THREE ZERO SIX SIX
# Target: NO
# Predicted: NO
# Target: NO
# Predicted: NO
# Target: C A R R E L
# Predicted: C A R R E L
# Target: NO
# Predicted: NO
# Target: THREE SIX THREE OH NINE SIX TWO
# Predicted: THREE SIX THREE OH NINE SIX TWO
# Target: N I C O L E
# Predicted: N I C O L E
# Target: A T T G K EIGHTY FOUR
# Predicted: A T T G K EIGHTY FOUR
# Target: RUBOUT Y Y F X ZERO
# Predicted: RUBOUT Y Y F X ZERO
# Target: ONE FIVE TWO TWO SIX
# Predicted: ONE FIVE TWO TWO SIX
# Target: RUBOUT W L F X Y SEVEN OH SIX NINE
# Predicted: RUBOUT W L F X Y SEVEN OH SIX NINE
# Target: V A D R THIRTY ONE OH SEVEN
# Predicted: V A D R THIRTY ONE OH SEVEN
# Target: A A I L ZERO
# Predicted: A A I L ZERO
# Target: RUBOUT V E W Z SEVEN SEVENTY TWO
# Predicted: RUBOUT V E W Z SEVEN SEVENTY TWO
# Target: NINE TWO TWO SEVEN TWO TWO ZERO
# Predicted: NINE TWO TWO SEVEN TWO TWO ZERO
# Target: RUBOUT Q Q Q P FORTY FIVE
# Predicted: RUBOUT Q Q Q P FORTY FIVE
# Target: ENTER SEVENTY EIGHT
# Predicted: ENTER SEVENTY EIGHT
# Target: M G E FOUR OH TWO
# Predicted: M G E FOUR OH TWO
# Target: C O N C O R D
# Predicted: C O N C O R D
# Target: FIFTY SIX SIXTY NINE
# Predicted: FIFTY SIX SIXTY NINE
# Target: ONE SIX OH SIX THREE
# Predicted: ONE SIX OH SIX THREE
# Target: ENTER EIGHT FOUR
# Predicted: ENTER EIGHT FOUR
# Target: T A N G L E W Y L D E
# Predicted: T A N G L E W Y L D E
# Target: ENTER SEVEN SEVEN
# Predicted: ENTER SEVEN SEVEN
# Target: I V A R S O N
# Predicted: I V A R S O N
# Target: F R A N C E S M A R Y
# Predicted: F R A N C E S M A R Y
# Target: M O R E W O O D
# Predicted: M O R E W O O D
# Target: ENTER TWO OH SEVEN
# Predicted: ENTER TWO OH SEVEN
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: A L L E V A
# Predicted: A L L E V A
# Target: B E V E R L Y
# Predicted: B E V E R L Y
# Target: RUBOUT M N Z L THREE SEVEN SEVEN
# Predicted: RUBOUT M N Z L THREE SEVEN SEVEN
# Target: REPEAT
# Predicted: REPEAT
# Target: ONE FIVE TWO OH SIX
# Predicted: ONE FIVE TWO OH SIX
# Target: FIFTY ONE FIFTEEN
# Predicted: FIFTY ONE FIFTEEN
# Target: P O M E R A N T Z
# Predicted: P O M E R A N T Z
# Target: Y F J K TWO EIGHT
# Predicted: Y F J K TWO EIGHT
# Target: G A R L A N D
# Predicted: G A R L A N D
# Target: W R I G H T S V I L L E
# Predicted: W R I G H T S V I L L E
# Target: M A P L E
# Predicted: M A P L E
# Target: SIX EIGHT THREE THREE SEVEN EIGHT ZERO
# Predicted: SIX EIGHT THREE THREE SEVEN EIGHT ZERO
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: SIX EIGHT ONE SEVEN SEVEN FIVE TWO
# Predicted: SIX EIGHT ONE SEVEN SEVEN FIVE TWO
# Target: G L L K H ONE
# Predicted: G L L K H ONE
# Target: J H B X THREE ZERO
# Predicted: J H B X THREE ZERO
# Target: SIX THREE SIXTY EIGHT
# Predicted: SIX THREE SIXTY EIGHT
# Target: NO
# Predicted: NO
# Target: EIGHT EIGHT TWO EIGHT ONE OH TWO
# Predicted: EIGHT EIGHT TWO EIGHT ONE OH TWO
# Target: A S P N E S
# Predicted: A S P N E S
# Target: REPEAT
# Predicted: REPEAT
# Target: M E A D O W G A T E D R I V E
# Predicted: M E A D O W G A T E D R I V E
# Target: ERASE Q E J Q T SEVENTY SEVEN
# Predicted: ERASE Q E J Q T SEVENTY SEVEN
# Target: ONE TWO FIVE TWO
# Predicted: ONE TWO FIVE TWO
# Target: N E W B U R Y
# Predicted: N E W B U R Y
# Target: R O Z E V E L D
# Predicted: R O Z E V E L D
# Target: YES
# Predicted: YES
# Target: ONE THOUSAND
# Predicted: ONE THOUSAND
# Target: SEVEN FOUR ONE OH FIVE NINE TWO
# Predicted: SEVEN FOUR ONE OH FIVE NINE TWO
# Target: TWO SIX EIGHT FIVE FIVE TWO FOUR
# Predicted: TWO SIX EIGHT FIVE FIVE TWO FOUR
# Target: RUBOUT J U I P THREE TWO EIGHT
# Predicted: RUBOUT J U I P THREE TWO EIGHT
# Target: JANUARY FIFTEENTH NINETEEN SIXTY THREE
# Predicted: JANUARY FIFTEENTH NINETEEN SIXTY THREE
# Target: ONE FIVE TWO THREE TWO
# Predicted: ONE FIVE TWO THREE TWO
# Target: G I B S O N I A
# Predicted: G I B S O N I A
# Target: RUBOUT Z O T F TWO
# Predicted: RUBOUT Z O T F TWO
# Target: START
# Predicted: START
# Target: TWO SIX EIGHT FOUR SIX FIVE EIGHT
# Predicted: TWO SIX EIGHT FOUR SIX FIVE EIGHT
# Target: FOUR ONE TWO FOUR TWO TWO THREE FIVE SEVEN EIGHT
# Predicted: FOUR ONE TWO FOUR TWO TWO THREE FIVE SEVEN EIGHT
# Target: ENTER SEVEN THIRTY EIGHT
# Predicted: ENTER SEVEN THIRTY EIGHT
# Target: EIGHTEEN FEBRUARY NINETEEN SEVENTY
# Predicted: EIGHTEEN FEBRUARY NINETEEN SEVENTY
# Target: OCTOBER TWENTY THIRD NINETEEN SIXTY SEVEN
# Predicted: OCTOBER TWENTY THIRD NINETEEN SIXTY SEVEN
# Target: J E T T
# Predicted: J E T T
# Target: B R I A N
# Predicted: B R I A N
# Target: FOUR ONE TWO SIX EIGHT ONE ONE EIGHT FOUR TWO
# Predicted: FOUR ONE TWO SIX EIGHT ONE ONE EIGHT FOUR TWO
# Target: EIGHT FOUR SIX SEVEN
# Predicted: EIGHT FOUR SIX SEVEN
# Target: STOP
# Predicted: STOP
# Target: ONE FIVE TWO THREE EIGHT
# Predicted: ONE FIVE TWO THREE EIGHT
# Target: B R A D F O R D W O O D S
# Predicted: B R A D F O R D W O O D S
# Target: B R U M I T T
# Predicted: B R U M I T T
# Target: START
# Predicted: START
# Target: FOUR ONE TWO FIVE TWO ONE EIGHT TWO SIX OH
# Predicted: FOUR ONE TWO FIVE TWO ONE EIGHT TWO SIX OH
# Target: V A L E
# Predicted: V A L E
# Target: ENTER SIX
# Predicted: ENTER SIX
# Target: ENTER SEVENTY ONE
# Predicted: ENTER SEVENTY ONE
# Target: ENTER FIFTY ONE
# Predicted: ENTER FIFTY ONE
# Target: B L A C K W O O D
# Predicted: B L A C K W O O D
# Target: ENTER FOUR FIFTY SIX
# Predicted: ENTER FOUR FIFTY SIX
# Target: ENTER SIXTY
# Predicted: ENTER SIXTY
# Target: ONE FIVE TWO ONE THREE
# Predicted: ONE FIVE TWO ONE THREE
# Target: ERASE O T E B SEVENTY NINE
# Predicted: ERASE O T E B SEVENTY NINE
# Target: ENTER FOUR
# Predicted: ENTER FOUR
# Target: ONE FIVE TWO ONE SEVEN
# Predicted: ONE FIVE TWO ONE SEVEN
# Target: START
# Predicted: START
# Target: RUBOUT N Z X L THIRTY ONE
# Predicted: RUBOUT N Z X L THIRTY ONE
# Target: ELEVEN SEVENTEEN FIFTY ONE
# Predicted: ELEVEN SEVENTEEN FIFTY ONE
# Target: R O B E R T
# Predicted: R O B E R T
# Target: REPEAT
# Predicted: REPEAT
# Target: SIX SIX ONE NINE EIGHT EIGHT FOUR
# Predicted: SIX SIX ONE NINE EIGHT EIGHT FOUR
# Target: ONE FIVE TWO ONE SEVEN
# Predicted: ONE FIVE TWO ONE SEVEN
# Target: V K Z O SIXTY TWO
# Predicted: V K Z O SIXTY TWO
# Target: M A S O N
# Predicted: M A S O N
# Target: A G L G A SIX FOUR NINE
# Predicted: A G L G A SIX FOUR NINE
# Target: D O N A L D
# Predicted: D O N A L D
# Target: ENTER NINE EIGHTY NINE
# Predicted: ENTER NINE EIGHTY NINE
# Target: J O S E P H
# Predicted: J O S E P H
# Target: ENTER EIGHTY NINE FORTY THREE
# Predicted: ENTER EIGHTY NINE FORTY THREE
# Target: EIGHT FOURTEEN SIXTY FOUR
# Predicted: EIGHT FOURTEEN SIXTY FOUR
# Target: ENTER SEVEN OH THREE EIGHT
# Predicted: ENTER SEVEN OH THREE EIGHT
# Target: ENTER THIRTY SEVEN
# Predicted: ENTER THIRTY SEVEN
# Target: ENTER FORTY ONE
# Predicted: ENTER FORTY ONE
# Target: THREE SEVENTY ONE
# Predicted: THREE SEVENTY ONE
# Target: B E R K E L E Y
# Predicted: B E R K E L E Y
# Target: FIFTY SEVEN FOURTEEN A
# Predicted: FIFTY SEVEN FOURTEEN A
# Target: M A U L D I N
# Predicted: M A U L D I N
# Target: S C A V I N C K Y
# Predicted: S C A V I N C K Y
# Target: B R A D D O C K
# Predicted: B R A D D O C K
# Target: C A R N E G I E
# Predicted: C A R N E G I E
# Target: FOUR TWO ONE OH ONE NINE SIX
# Predicted: FOUR TWO ONE OH ONE NINE SIX
# Target: DECEMBER EIGHTEENTH NINETEEN FORTY FOUR
# Predicted: DECEMBER EIGHTEENTH NINETEEN FORTY FOUR
# Target: F Y Z O TWO TWO TWO
# Predicted: F Y Z O TWO TWO TWO
# Target: O L D B A R N D R I V E
# Predicted: O L D B A R N D R I V E
# Target: M M V Q D ONE EIGHT SEVEN
# Predicted: M M V Q D ONE EIGHT SEVEN
# Target: ELEVEN NINE SIXTY EIGHT
# Predicted: ELEVEN NINE SIXTY EIGHT
# Target: ERASE C K C W FOURTEEN EIGHTY FIVE
# Predicted: ERASE C K C W FOURTEEN EIGHTY FIVE
# Target: ENTER THREE EIGHTY SIX
# Predicted: ENTER THREE EIGHTY SIX
# Target: J C H E Q FIFTY EIGHT THOUSAND NINE THIRTY NINE
# Predicted: J C H E Q FIFTY EIGHT THOUSAND NINE THIRTY NINE
# Target: ENTER SEVEN
# Predicted: ENTER SEVEN
# Target: G R E E N
# Predicted: G R E E N
# Target: M I D W O O D
# Predicted: M I D W O O D
# Target: YES
# Predicted: YES
# Target: M A R Y J O
# Predicted: M A R Y J O
# Target: ENTER FIFTY FIVE
# Predicted: ENTER FIFTY FIVE
# Target: STOP
# Predicted: STOP
# Target: AUGUST TWENTY SECOND NINETEEN SIXTY ONE
# Predicted: AUGUST TWENTY SECOND NINETEEN SIXTY ONE
# Target: S T E V E N
# Predicted: S T E V E N
# Target: HELP
# Predicted: HELP
# Target: E A S T E N D A V E N U E
# Predicted: E A S T E N D A V E N U E
# Target: I P A C F TWO FIVE EIGHT
# Predicted: I P A C F TWO FIVE EIGHT
# Target: RUBOUT U J M K NINE
# Predicted: RUBOUT U J M K NINE
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: ENTER SEVEN
# Predicted: ENTER SEVEN
# Target: D A V I D
# Predicted: D A V I D
# Target: E R I C
# Predicted: E R I C
# Target: GO
# Predicted: GO
# Target: FOUR OH ONE
# Predicted: FOUR OH ONE
# Target: B R O O M A L L
# Predicted: B R O O M A L L
# Target: P G H
# Predicted: P G H
# Target: ENTER SIXTY ONE
# Predicted: ENTER SIXTY ONE
# Target: FOUR TWO ONE SIX TWO EIGHT THREE
# Predicted: FOUR TWO ONE SIX TWO EIGHT THREE
# Target: F I N D L E Y D R I V E
# Predicted: F I N D L E Y D R I V E
# Target: FOUR FOUR FOUR EIGHT FOUR
# Predicted: FOUR FOUR FOUR EIGHT FOUR
# Target: RUBOUT G J H G V SEVEN
# Predicted: RUBOUT G J H G V SEVEN
# Target: ENTER TWENTY NINE
# Predicted: ENTER TWENTY NINE
# Target: G W N L L NINE FOUR
# Predicted: G W N L L NINE FOUR
# Target: M A C A L U S O
# Predicted: M A C A L U S O
# Target: L E W I S
# Predicted: L E W I S
# Target: ONE FIVE TWO TWO ONE
# Predicted: ONE FIVE TWO TWO ONE
# Target: FIVE SIXTEEN SIXTY NINE
# Predicted: FIVE SIXTEEN SIXTY NINE
# Target: GO
# Predicted: GO
# Target: HELP
# Predicted: HELP
# Target: NINE TWENTY THREE SIXTY THREE
# Predicted: NINE TWENTY THREE SIXTY THREE
# Target: M F G I K TWO SIXTY
# Predicted: M F G I K TWO SIXTY
# Target: FOUR TWO TWO OH EIGHT ONE SIX
# Predicted: FOUR TWO TWO OH EIGHT ONE SIX
# Target: TWO TWENTY FOUR FORTY NINE
# Predicted: TWO TWENTY FOUR FORTY NINE
# Target: R H H U F TWO
# Predicted: R H H U F TWO
# Target: Y D N E D FORTY SEVEN
# Predicted: Y D N E D FORTY SEVEN
# Target: F I Y Q FIFTY SIX
# Predicted: F I Y Q FIFTY SIX
# Target: S M I T H
# Predicted: S M I T H
# Target: REPEAT
# Predicted: REPEAT
# Target: ONE FIVE TWO ONE SEVEN
# Predicted: ONE FIVE TWO ONE SEVEN
# Target: ERASE S V N Y TEN TEN
# Predicted: ERASE S V N Y TEN TEN
# Target: ONE FOUR EIGHT FIVE OH
# Predicted: ONE FOUR EIGHT FIVE OH
# Target: C R A F T O N
# Predicted: C R A F T O N
# Target: L A M P S O N
# Predicted: L A M P S O N
# Target: F A R R E L L Y
# Predicted: F A R R E L L Y
# Target: RUBOUT U G A M THIRTY NINE
# Predicted: RUBOUT U G A M THIRTY NINE
# Target: P T Q D Q ONE
# Predicted: P T Q D Q ONE
# Target: E A S T EIGHTY FIFTH S T R E E T
# Predicted: E A S T EIGHTY FIFTH S T R E E T
# Target: YES
# Predicted: YES
# Target: ONE FIVE TWO ONE THREE
# Predicted: ONE FIVE TWO ONE THREE
# Target: THIRTY ONE J A N U A R Y ONE NINE SEVEN ZERO
# Predicted: THIRTY ONE J A N U A R Y ONE NINE SEVEN ZERO
# Target: FOUR FOUR THREE SIX THREE ONE TWO
# Predicted: FOUR FOUR THREE SIX THREE ONE TWO
# Target: S T E V E N
# Predicted: S T E V E N
# Target: O U FOUR SEVEN TWENTY NINE
# Predicted: O U FOUR SEVEN TWENTY NINE
# Target: HELP
# Predicted: HELP
# Target: ENTER FIFTEEN
# Predicted: ENTER FIFTEEN
# Target: FIVE ONE ONE FIVE
# Predicted: FIVE ONE ONE FIVE
# Target: M A H O N E Y
# Predicted: M A H O N E Y
# Target: ENTER FIVE TWO FOUR
# Predicted: ENTER FIVE TWO FOUR
# Target: THREE TWELVE FIFTY EIGHT
# Predicted: THREE TWELVE FIFTY EIGHT
# Target: W H I T N E Y
# Predicted: W H I T N E Y
# Target: RUBOUT N X F E EIGHT NINE SIX
# Predicted: RUBOUT N X F E EIGHT NINE SIX
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: B A I Q W EIGHT
# Predicted: B A I Q W EIGHT
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: RUBOUT W P F J D TWO SIX
# Predicted: RUBOUT W P F J D TWO SIX
# Target: TWO ONE FIVE FOUR FIVE EIGHT FIVE FOUR SIX NINE
# Predicted: TWO ONE FIVE FOUR FIVE EIGHT FIVE FOUR SIX NINE
# Target: M E M O R Y L A N E
# Predicted: M E M O R Y L A N E
# Target: H A W T H O R N E
# Predicted: H A W T H O R N E
# Target: FOUR ONE TWO FOUR TWO ONE EIGHT EIGHT NINE SIX
# Predicted: FOUR ONE TWO FOUR TWO ONE EIGHT EIGHT NINE SIX
# Target: RUBOUT H W O N J FOUR THOUSAND SEVEN HUNDRED TWENTY THREE
# Predicted: RUBOUT H W O N J FOUR THOUSAND SEVEN HUNDRED TWENTY THREE
# Target: ONE FIVE TWO ONE SEVEN
# Predicted: ONE FIVE TWO ONE SEVEN
# Target: ONE FIVE TWO ONE THREE
# Predicted: ONE FIVE TWO ONE THREE
# Target: YES
# Predicted: YES
# Target: J Z A P SEVENTEEN
# Predicted: J Z A P SEVENTEEN
# Target: K A R E N
# Predicted: K A R E N
# Target: ENTER SEVEN TWO ONE SIX
# Predicted: ENTER SEVEN TWO ONE SIX
# Target: HELP
# Predicted: HELP
# Target: RUBOUT N A F K V THIRTY
# Predicted: RUBOUT N A F K V THIRTY
# Target: E A R L F O R D
# Predicted: E A R L F O R D
# Target: S E P T E M B E R ONE TWO ONE NINE FIVE NINE
# Predicted: S E P T E M B E R ONE TWO ONE NINE FIVE NINE
# Target: J V P E EIGHT SEVEN ZERO
# Predicted: J V P E EIGHT SEVEN ZERO
# Target: J E F F
# Predicted: J E F F
# Target: ENTER SEVEN
# Predicted: ENTER SEVEN
# Target: N E I L
# Predicted: N E I L
# Target: APRIL THIRTIETH NINETEEN SIXTY NINE
# Predicted: APRIL THIRTIETH NINETEEN SIXTY NINE
# Target: RUBOUT E U J O NINETY FIVE
# Predicted: RUBOUT E U J O NINETY FIVE
# Target: W I L K I N S
# Predicted: W I L K I N S
# Target: S U M M E R L E A
# Predicted: S U M M E R L E A
# Target: ONE TWENTY TWO
# Predicted: ONE TWENTY TWO
# Target: E Z A K O EIGHT
# Predicted: E Z A K O EIGHT
# Target: ONE FIVE TWO TWO ONE
# Predicted: ONE FIVE TWO TWO ONE
# Target: S T E E R E
# Predicted: S T E E R E
# Target: ENTER TWO SIX
# Predicted: ENTER TWO SIX
# Target: D O W L I N G
# Predicted: D O W L I N G
# Target: M A R G A R E T
# Predicted: M A R G A R E T
# Target: ONE OH SEVEN OH EIGHT
# Predicted: ONE OH SEVEN OH EIGHT
# Target: ONE HUNDRED
# Predicted: ONE HUNDRED
# Target: TWELVE NINETEEN SIXTY NINE
# Predicted: TWELVE NINETEEN SIXTY NINE
# Target: TWO ONE TWO FIVE SEVEN OH TWO SEVEN EIGHT FOUR
# Predicted: TWO ONE TWO FIVE SEVEN OH TWO SEVEN EIGHT FOUR
# Target: H K T E D ONE SEVENTY
# Predicted: H K T E D ONE SEVENTY
# Target: TWO FOUR TWO TWO NINE ONE TWO
# Predicted: TWO FOUR TWO TWO NINE ONE TWO
# Target: RUBOUT T J J C L TWO
# Predicted: RUBOUT T J J C L TWO
# Target: M A R K
# Predicted: M A R K
# Target: L U D W I C K
# Predicted: L U D W I C K
# Target: ENTER NINE
# Predicted: ENTER NINE
# Target: RUBOUT R Z R V Z NINETY EIGHT
# Predicted: RUBOUT R Z R V Z NINETY EIGHT
# Target: T R A C Y
# Predicted: T R A C Y
# Target: START
# Predicted: START
# Target: TWO SIX EIGHT THREE EIGHT ZERO TWO
# Predicted: TWO SIX EIGHT THREE EIGHT ZERO TWO
# Target: FIVE TEN
# Predicted: FIVE TEN
# Target: ONE FIVE TWO ONE THREE
# Predicted: ONE FIVE TWO ONE THREE
# Target: X Z I V Y ONE
# Predicted: X Z I V Y ONE
# Target: MAY NINTH SIXTY TWO
# Predicted: MAY NINTH SIXTY TWO
# Target: ONE FIVE TWO ONE SEVEN
# Predicted: ONE FIVE TWO ONE SEVEN
# Target: ENTER TWO FIVE FOUR SIX
# Predicted: ENTER TWO FIVE FOUR SIX
# Target: C H R I S
# Predicted: C H R I S
# Target: SIX SIX FIVE NINE SIX SIX FIVE
# Predicted: SIX SIX FIVE NINE SIX SIX FIVE
# Target: N H O T Q TWO EIGHT THREE
# Predicted: N H O T Q TWO EIGHT THREE
# Target: ENTER SEVENTY ONE
# Predicted: ENTER SEVENTY ONE
# Target: ERASE W E S F TWENTY FOUR OH THREE
# Predicted: ERASE W E S F TWENTY FOUR OH THREE
# Target: REPEAT
# Predicted: REPEAT
# Target: OCTOBER THIRTIETH NINETEEN SIXTY ONE
# Predicted: OCTOBER THIRTIETH NINETEEN SIXTY ONE
# Target: RUBOUT Q N R A J SEVEN FOUR EIGHT
# Predicted: RUBOUT Q N R A J SEVEN FOUR EIGHT
# Target: ONE FIVE TWO ONE SEVEN
# Predicted: ONE FIVE TWO ONE SEVEN
# Target: HELP
# Predicted: HELP
# Target: RUBOUT U F Z Z SIXTY NINE
# Predicted: RUBOUT U F Z Z SIXTY NINE
# Target: ENTER NINE EIGHT NINE
# Predicted: ENTER NINE EIGHT NINE
# Target: ENTER SIXTY FOUR
# Predicted: ENTER SIXTY FOUR
# Target: W A R R E N
# Predicted: W A R R E N
# Target: RUBOUT T B P B SIX
# Predicted: RUBOUT T B P B SIX
# Target: EIGHT EIGHT FOUR ONE ZERO FIVE SEVEN
# Predicted: EIGHT EIGHT FOUR ONE ZERO FIVE SEVEN
# Target: D Y M H R SIXTY ONE
# Predicted: D Y M H R SIXTY ONE
# Target: FOUR FOUR ONE ONE SEVEN TWO FOUR
# Predicted: FOUR FOUR ONE ONE SEVEN TWO FOUR
# Target: RUBOUT C Y R B SEVEN EIGHT
# Predicted: RUBOUT C Y R B SEVEN EIGHT
# Target: SEVEN NINE THREE FIVE FOUR TWO NINE
# Predicted: SEVEN NINE THREE FIVE FOUR TWO NINE
# Target: ONE TEN
# Predicted: ONE TEN
# Target: J FOUR THIRTY THREE
# Predicted: J FOUR THIRTY THREE
# Target: P H I L L I P S
# Predicted: P H I L L I P S
# Target: H Q F X FOUR THOUSAND THREE HUNDRED AND EIGHTY SIX
# Predicted: H Q F X FOUR THOUSAND THREE HUNDRED EIGHTY SIX
# Target: P G H
# Predicted: P G H
# Target: TWO OH THREE SEVEN FIVE SEVEN EIGHT EIGHT NINE NINE
# Predicted: TWO OH THREE SEVEN FIVE SEVEN EIGHT EIGHT NINE NINE
# Target: L E U L I E T T E
# Predicted: L E U L I E T T E
# Target: RUBOUT V A N B X NINE
# Predicted: RUBOUT V A N B X NINE
# Target: STOP
# Predicted: STOP
# Target: L U B I N S K I
# Predicted: L U B I N S K I
# Target: J A M E S
# Predicted: J A M E S
# Target: REPEAT
# Predicted: REPEAT
# Target: ENTER FIFTY FOUR
# Predicted: ENTER FIFTY FOUR
# Target: FIVE TWO ONE OH TWO SIX EIGHT
# Predicted: FIVE TWO ONE OH TWO SIX EIGHT
# Target: SEVEN FIFTEEN NINETEEN SEVENTY
# Predicted: SEVEN FIFTEEN NINETEEN SEVENTY
# Target: ENTER SIXTY
# Predicted: ENTER SIXTY
# Target: THREE TWENTY SEVEN SIXTY EIGHT
# Predicted: THREE TWENTY SEVEN SIXTY EIGHT
# Target: FOUR SEVEN SIXTY FOUR
# Predicted: FOUR SEVEN SIXTY FOUR
# Target: RUBOUT E Z U A I FIFTEEN
# Predicted: RUBOUT E Z U A I FIFTEEN
# Target: FOUR ONE TWO TWO FOUR TWO SIX SIX TWO SIX
# Predicted: FOUR ONE TWO TWO FOUR TWO SIX SIX TWO SIX
# Target: R O S E N F E L D
# Predicted: R O S E N F E L D
# Target: T A Y L O R
# Predicted: T A Y L O R
# Target: H B G L SEVENTY SEVEN
# Predicted: H B G L SEVENTY SEVEN
# Target: TWO SEVEN ONE ZERO EIGHT TWO SIX
# Predicted: TWO SEVEN ONE ZERO EIGHT TWO SIX
# Target: T I M M
# Predicted: T I M M
# Target: ONE FOUR EIGHT TWO THREE
# Predicted: ONE FOUR EIGHT TWO THREE
# Target: P A R K R O A D
# Predicted: P A R K R O A D
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: ERASE G H X W FIVE ZERO FOUR EIGHT TWO
# Predicted: ERASE G H X W FIVE ZERO FOUR EIGHT TWO
# Target: RUBOUT O G D E FOUR SEVEN FIVE SEVEN
# Predicted: RUBOUT O G D E FOUR SEVEN FIVE SEVEN
# Target: ONE FIFTY
# Predicted: ONE FIFTY
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: E F R O M
# Predicted: E F R O M
# Target: STOP
# Predicted: STOP
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: ENTER EIGHT SEVENTY ONE
# Predicted: ENTER EIGHT SEVENTY ONE
# Target: ONE FIVE TWO ONE SEVEN
# Predicted: ONE FIVE TWO ONE SEVEN
# Target: I T H A C A
# Predicted: I T H A C A
# Target: NO
# Predicted: NO
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: SIX SIX FOUR SEVEN TWO NINE THREE
# Predicted: SIX SIX FOUR SEVEN TWO NINE THREE
# Target: C L A R K
# Predicted: C L A R K
# Target: RUBOUT O K T L E TWO EIGHT ONE
# Predicted: RUBOUT O K T L E TWO EIGHT ONE
# Target: THIRTY TWO THIRTY ONE
# Predicted: THIRTY TWO THIRTY ONE
# Target: ERASE M Y A M SEVEN
# Predicted: ERASE M Y A M SEVEN
# Target: ONE FIVE TWO ONE THREE
# Predicted: ONE FIVE TWO ONE THREE
# Target: S A T T E R F I E L D
# Predicted: S A T T E R F I E L D
# Target: EIGHT TWO SIX EIGHT SIX EIGHT SEVEN
# Predicted: EIGHT TWO SIX EIGHT SIX EIGHT SEVEN
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: ERASE I G N M FORTY THREE SEVENTEEN
# Predicted: ERASE I G N M FORTY THREE SEVENTEEN
# Target: ONE FIVE TWO OH FIVE
# Predicted: ONE FIVE TWO OH FIVE
# Target: ONE FIVE SIX SIX EIGHT
# Predicted: ONE FIVE SIX SIX EIGHT
# Target: E M B Z SIX EIGHT SIX
# Predicted: E M B Z SIX EIGHT SIX
# Target: S T E V E N
# Predicted: S T E V E N
# Target: ERASE R B D K T FIFTY
# Predicted: ERASE R B D K T FIFTY
# Target: ONE FIVE OH FOUR FOUR
# Predicted: ONE FIVE OH FOUR FOUR
# Target: M O D U G N O
# Predicted: M O D U G N O
# Target: FOUR FOUR FOUR SEVEN
# Predicted: FOUR FOUR FOUR SEVEN
# Target: F E B ONE EIGHT ONE NINE SIX FOUR
# Predicted: F E B ONE EIGHT ONE NINE SIX FOUR
# Target: C E N T R E A V E N U E
# Predicted: C E N T R E A V E N U E
# Target: ONE TWO SEVEN SIX THREE
# Predicted: ONE TWO SEVEN SIX THREE
# Target: ENTER FORTY SEVEN FORTY SEVEN
# Predicted: ENTER FORTY SEVEN FORTY SEVEN
# Target: JUNE ELEVENTH NINETEEN SIXTY SEVEN
# Predicted: JUNE ELEVENTH NINETEEN SIXTY SEVEN
# Target: ENTER NINE SEVENTY TWO
# Predicted: ENTER NINE SEVENTY TWO
# Target: J U L I E
# Predicted: J U L I E
# Target: REPEAT
# Predicted: REPEAT
# Target: O R C H A R D P L A C E
# Predicted: O R C H A R D P L A C E
# Target: ENTER ONE THIRTY ONE
# Predicted: ENTER ONE THIRTY ONE
# Target: THREE ELEVEN SIXTY SEVEN
# Predicted: THREE ELEVEN SIXTY SEVEN
# Target: FIFTY SIX OH FIVE
# Predicted: FIFTY SIX OH FIVE
# Target: NO
# Predicted: NO
# Target: T E R I N A
# Predicted: T E R I N A
# Target: THREE FOUR EIGHT ZERO
# Predicted: THREE FOUR EIGHT ZERO
# Target: SIX THREE TWO THREE
# Predicted: SIX THREE TWO THREE
# Target: T H O M A S
# Predicted: T H O M A S
# Target: G O T T I E R
# Predicted: G O T T I E R
# Target: JUNE TWENTY THIRD NINETEEN SIXTY NINE
# Predicted: JUNE TWENTY THIRD NINETEEN SIXTY NINE
# Target: M O R E W O O D
# Predicted: M O R E W O O D
# Target: Z E L I E N O P L E
# Predicted: Z E L I E N O P L E
# Target: A L M O N T
# Predicted: A L M O N T
# Target: A V M U FOUR FORTY TWO
# Predicted: A V M U FOUR FORTY TWO
# Target: YES
# Predicted: YES
# Target: H O W E L L
# Predicted: H O W E L L
# Target: RUBOUT P N A M X SEVENTY TWO
# Predicted: RUBOUT P N A M X SEVENTY TWO
# Target: ONE SEVEN THREE SIX EIGHT
# Predicted: ONE SEVEN THREE SIX EIGHT
# Target: P H Y L L I S
# Predicted: P H Y L L I S
# Target: SIX THIRTY
# Predicted: SIX THIRTY
# Target: RUBOUT M D M T G NINE SIX SEVEN OH
# Predicted: RUBOUT M D M T G NINE SIX SEVEN OH
# Target: ERASE V X S X TWO FOUR NINE NINE
# Predicted: ERASE V X S X TWO FOUR NINE NINE
# Target: GO
# Predicted: GO
# Target: B E E L E R
# Predicted: B E E L E R
# Target: ENTER ONE NINETY SIX
# Predicted: ENTER ONE NINETY SIX
# Target: RUBOUT N B A K NINETY SIX
# Predicted: RUBOUT N B A K NINETY SIX
# Target: Q E E A SIX
# Predicted: Q E E A SIX
# Target: REPEAT
# Predicted: REPEAT
# Target: TEN TWENTY EIGHT SIXTY NINE
# Predicted: TEN TWENTY EIGHT SIXTY NINE
# Target: START
# Predicted: START
# Target: ONE FIVE TWO FOUR ONE
# Predicted: ONE FIVE TWO FOUR ONE
# Target: K A R L A
# Predicted: K A R L A
# Target: ENTER ZERO
# Predicted: ENTER ZERO
# Target: P I T T S B U R G
# Predicted: P I T T S B U R G
# Target: HELP
# Predicted: HELP
# Target: ENTER FIVE THREE FOUR THREE
# Predicted: ENTER FIVE THREE FOUR THREE
# Target: ONE FIVE TWO THREE TWO
# Predicted: ONE FIVE TWO THREE TWO
# Target: M I C H A E L
# Predicted: M I C H A E L
# Target: ENTER TWO
# Predicted: ENTER TWO
# Target: RUBOUT R E F V S ONE FIVE THREE THREE
# Predicted: RUBOUT R E F V S ONE FIVE THREE THREE
# Target: MARCH TWENTY FIFTH NINETEEN SIXTY SEVEN
# Predicted: MARCH TWENTY FIFTH NINETEEN SIXTY SEVEN
# Target: RUBOUT U T F F EIGHT
# Predicted: RUBOUT U T F F EIGHT
# Target: R I C H A R D
# Predicted: R I C H A R D
# Target: V F O F H NINE FOUR
# Predicted: V F O F H NINE FOUR
# Target: NO
# Predicted: NO
# Target: ENTER FIVE
# Predicted: ENTER FIVE
# Target: START
# Predicted: START
# Target: THREE TWENTY EIGHT SIXTY ONE
# Predicted: THREE TWENTY EIGHT SIXTY ONE
# Target: ENTER FIFTY FOUR
# Predicted: ENTER FIFTY FOUR
# Target: FIVE TWO ONE SIXTY FIFTY FIVE
# Predicted: FIVE TWO ONE SIXTY FIFTY FIVE
# Target: F K A U TWO FOUR
# Predicted: F K A U TWO FOUR
# Target: C Z D Z W EIGHT
# Predicted: C Z D Z W EIGHT
# Target: E L G I N
# Predicted: E L G I N
# Target: ENTER SIXTY
# Predicted: ENTER SIXTY
# Target: FOUR EIGHT SIX THREE NINE FIVE OH
# Predicted: FOUR EIGHT SIX THREE NINE FIVE OH
# Target: D A L Z E L L
# Predicted: D A L Z E L L
# Target: O APOSTROPHE H A R A
# Predicted: O P H A R A
# Target: FOUR EIGHT FOUR TWO
# Predicted: FOUR EIGHT FOUR TWO
# Target: J E A N
# Predicted: J E A N
# Target: ENTER SIX FOUR FIVE ONE
# Predicted: ENTER SIX FOUR FIVE ONE
# Target: ONE FIVE ONE OH SIX
# Predicted: ONE FIVE ONE OH SIX
# Target: THREE FOUR FOUR
# Predicted: THREE FOUR FOUR
# Target: TWO NINE SIX SIX TWO
# Predicted: TWO NINE SIX SIX TWO
# Target: S E M P L E
# Predicted: S E M P L E
# Target: ERASE E O A C U THREE
# Predicted: ERASE E O A C U THREE
# Target: H A S T I N G S
# Predicted: H A S T I N G S
# Target: ENTER EIGHT TWENTY SEVEN
# Predicted: ENTER EIGHT TWENTY SEVEN
# Target: G I B B S
# Predicted: G I B B S
# Target: REPEAT
# Predicted: REPEAT
# Target: N G N N THREE NINE NINE
# Predicted: N G N N THREE NINE NINE
# Target: ONE ZERO ZERO SIX
# Predicted: ONE ZERO ZERO SIX
# Target: ONE FIVE OH ONE FIVE
# Predicted: ONE FIVE OH ONE FIVE
# Target: E D W I N
# Predicted: E D W I N
# Target: R I C H A R D
# Predicted: R I C H A R D
# Target: N N P U FIVE
# Predicted: N N P U FIVE
# Target: ENTER THIRTY FIVE
# Predicted: ENTER THIRTY FIVE
# Target: ENTER EIGHT ZERO SIX
# Predicted: ENTER EIGHT ZERO SIX
# Target: FIVE SIX ONE FIVE
# Predicted: FIVE SIX ONE FIVE
# Target: Z I R K SIX FOUR FOUR
# Predicted: Z I R K SIX FOUR FOUR
# Target: ERASE V Y W L R SEVEN ZERO ONE ONE
# Predicted: ERASE V Y W L R SEVEN ZERO ONE ONE
# Target: F O R W A R D
# Predicted: F O R W A R D
# Target: J O N A T H A N
# Predicted: J O N A T H A N
# Target: O A W F FIVE NINE
# Predicted: O A W F FIVE NINE
# Target: FIVE T H A V E N U E
# Predicted: FIVE T H A V E N U E
# Target: STOP
# Predicted: STOP
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: A S B U R Y P L A C E
# Predicted: A S B U R Y P L A C E
# Target: TWO SIX EIGHT THREE ZERO TWO SEVEN
# Predicted: TWO SIX EIGHT THREE ZERO TWO SEVEN
# Target: THIRTY THREE
# Predicted: THIRTY THREE
# Target: W E I D E
# Predicted: W E I D E
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: B Y V M EIGHT FOUR
# Predicted: B Y V M EIGHT FOUR
# Target: FIVE ONE ONE FIVE M A R G A R E T
# Predicted: FIVE ONE ONE FIVE M A R G A R E T
# Target: YES
# Predicted: YES
# Target: MAY TWENTY FIRST NINETEEN SIXTY
# Predicted: MAY TWENTY FIRST NINETEEN SIXTY
# Target: P T K X ZERO
# Predicted: P T K X ZERO
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: EIGHT FIVE SIX ONE FOUR NINE ZERO
# Predicted: EIGHT FIVE SIX ONE FOUR NINE ZERO
# Target: ENTER SIXTY TWO THIRTY ONE
# Predicted: ENTER SIXTY TWO THIRTY ONE
# Target: H O B A R T
# Predicted: H O B A R T
# Target: D A N I E L
# Predicted: D A N I E L
# Target: J A M E S
# Predicted: J A M E S
# Target: OCTOBER FIRST NINETEEN SIXTY NINE
# Predicted: OCTOBER FIRST NINETEEN SIXTY NINE
# Target: NO
# Predicted: NO
# Target: K A R L
# Predicted: K A R L
# Target: RUBOUT I R D D J ONE
# Predicted: RUBOUT I R D D J ONE
# Target: T I M O T H Y
# Predicted: T I M O T H Y
# Target: B U R C H F E I L D A V E
# Predicted: B U R C H F E I L D A V E
# Target: A M P E R E
# Predicted: A M P E R E
# Target: RUBOUT M V O O FORTY SIX
# Predicted: RUBOUT M V O O FORTY SIX
# Target: TWO FOUR THREE EIGHT THREE TWO EIGHT
# Predicted: TWO FOUR THREE EIGHT THREE TWO EIGHT
# Target: RUBOUT O H G P D TWO NINE SEVEN SIX
# Predicted: RUBOUT O H G P D TWO NINE SEVEN SIX
# Target: X I SIXTY ONE
# Predicted: X I SIXTY ONE
# Target: ONE FIVE THREE TWO
# Predicted: ONE FIVE THREE TWO
# Target: K U N T Z
# Predicted: K U N T Z
# Target: V E R O N A
# Predicted: V E R O N A
# Target: ERASE Q K X Y U ONE SIXTY TWO
# Predicted: ERASE Q K X Y U ONE SIXTY TWO
# Target: FOUR TWO TWO ZERO SEVEN NINE ONE
# Predicted: FOUR TWO TWO ZERO SEVEN NINE ONE
# Target: RUBOUT L D R W TWENTY SIX
# Predicted: RUBOUT L D R W TWENTY SIX
# Target: W A T E R B U R Y
# Predicted: W A T E R B U R Y
# Target: SIXTY THREE SIXTY FOUR AND A HALF
# Predicted: SIXTY THREE SIXTY FOUR AND A
# Target: J O S E P H
# Predicted: J O S E P H
# Target: C L O U T I E R
# Predicted: C L O U T I E R
# Target: RUBOUT C H Y D D OH
# Predicted: RUBOUT C H Y D D OH
# Target: JULY THIRTIETH NINETEEN SIXTY FIVE
# Predicted: JULY THIRTIETH NINETEEN SIXTY FIVE
# Target: FIVE SIX FOUR ZERO
# Predicted: FIVE SIX FOUR ZERO
# Target: NO
# Predicted: NO
# Target: TEN THIRTY ONE FIFTY EIGHT
# Predicted: TEN THIRTY ONE FIFTY EIGHT
# Target: ONE FIVE TWO ONE SEVEN
# Predicted: ONE FIVE TWO ONE SEVEN
# Target: N E W Y O R K
# Predicted: N W Y O R K
# Target: T R E N T O N
# Predicted: T R E N T O N
# Target: FIVE ONE NINE
# Predicted: FIVE ONE NINE
# Target: G C D O FOUR
# Predicted: G C D O FOUR
# Target: S T E V E N
# Predicted: S T E V E N
# Target: W I L L I A M S
# Predicted: W I L L I A M S
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: J O H N S O N
# Predicted: J O H N S O N
# Target: SIX FIVE THREE FOUR
# Predicted: SIX FIVE THREE FOUR
# Target: F I F T H A V E N U E
# Predicted: F I F T H A V E N U E
# Target: SEPTEMBER SIXTH NINETEEN SIXTY SEVEN
# Predicted: SEPTEMBER SIXTH NINETEEN SIXTY SEVEN
# Target: GO
# Predicted: GO
# Target: ONE THIRTY ONE SIXTY THREE
# Predicted: ONE THIRTY ONE SIXTY THREE
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: ERASE I S L F THIRTY EIGHT
# Predicted: ERASE I S L F THIRTY EIGHT
# Target: NO
# Predicted: NO
# Target: C I N D Y
# Predicted: C I N D Y
# Target: SIX ZERO ONE FIVE
# Predicted: SIX ZERO ONE FIVE
# Target: SIX SEVENTEEN THIRTY SIX
# Predicted: SIX SEVENTEEN THIRTY SIX
# Target: B R O W N
# Predicted: B R O W N
# Target: YES
# Predicted: YES
# Target: R E W Y EIGHT FIVE SIX
# Predicted: R E W Y EIGHT FIVE SIX
# Target: I D M H SEVEN EIGHT FIVE
# Predicted: I D M H SEVEN EIGHT FIVE
# Target: THREE OH SIX
# Predicted: THREE OH SIX
# Target: TWO SIX EIGHT FIVE NINE FIVE TWO
# Predicted: TWO SIX EIGHT FIVE NINE FIVE TWO
# Target: RUBOUT O Q I M I THIRTY TWO
# Predicted: RUBOUT O Q I M I THIRTY TWO
# Target: S F Q Q K SIX THOUSAND EIGHT HUNDRED AND EIGHTY ONE
# Predicted: S F Q Q K SIX THOUSAND EIGHT HUNDRED EIGHTY ONE
# Target: G A B H TWO
# Predicted: G A B H TWO
# Target: B R O A D H E A D R O A D
# Predicted: B R O A D H E A D R O A D
# Target: V E C C H I
# Predicted: V E C C H I
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: START
# Predicted: START
# Target: ERASE F H B K Z SIXTY NINE
# Predicted: ERASE F H B K Z SIXTY NINE
# Target: ONE FIVE TWO ONE SEVEN
# Predicted: ONE FIVE TWO ONE SEVEN
# Target: FOUR ONE TWO FIVE TWO ONE TWO EIGHT TWO FOUR
# Predicted: FOUR ONE TWO FIVE TWO ONE TWO EIGHT TWO FOUR
# Target: ENTER SEVEN
# Predicted: ENTER SEVEN
# Target: ONE FIVE OH FOUR FOUR
# Predicted: ONE FIVE OH FOUR FOUR
# Target: REPEAT
# Predicted: REPEAT
# Target: NO
# Predicted: NO
# Target: YES
# Predicted: YES
# Target: SIX SIXTEEN SIXTY
# Predicted: SIX SIXTEEN SIXTY
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: REPEAT
# Predicted: REPEAT
# Target: RUBOUT J B X R Z NINE TWENTY
# Predicted: RUBOUT J B X R Z NINE TWENTY
# Target: REPEAT
# Predicted: REPEAT
# Target: YES
# Predicted: YES
# Target: AUGUST TWENTY FOURTH NINETEEN FIFTY TWO
# Predicted: AUGUST TWENTY FOURTH NINETEEN FIFTY TWO
# Target: JULY TWELFTH NINETEEN SIXTY NINE
# Predicted: JULY TWELFTH NINETEEN SIXTY NINE
# Target: ENTER SIX SEVEN
# Predicted: ENTER SIX SEVEN
# Target: H P D F T SIXTY THREE
# Predicted: H P D F T SIXTY THREE
# Target: NO
# Predicted: NO
# Target: JANUARY TWELFTH NINETEEN SIXTY SIX
# Predicted: JANUARY TWELFTH NINETEEN SIXTY SIX
# Target: TWO SIX EIGHT FOUR ONE SIX ONE
# Predicted: TWO SIX EIGHT FOUR ONE SIX ONE
# Target: TWO FIFTEEN SIXTY TWO
# Predicted: TWO FIFTEEN SIXTY TWO
# Target: ENTER SIX
# Predicted: ENTER SIX
# Target: FOUR SEVEN TWO ZERO
# Predicted: FOUR SEVEN TWO ZERO
# Target: ENTER EIGHT THIRTY TWO
# Predicted: ENTER EIGHT THIRTY TWO
# Target: FIVE TWO FIVE FIVE FIVE
# Predicted: FIVE TWO FIVE FIVE FIVE
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: B U R K S
# Predicted: B U R K S
# Target: D S K U FOUR FIVE OH FIVE
# Predicted: D S K U FOUR FIVE OH FIVE
# Target: TWO SIX EIGHT FOUR FOUR ONE EIGHT
# Predicted: TWO SIX EIGHT FOUR FOUR ONE EIGHT
# Target: D R A V K
# Predicted: D R A V K
# Target: ONE SEVEN FORTY SEVEN
# Predicted: ONE SEVEN FORTY SEVEN
# Target: STOP
# Predicted: STOP
# Target: FIFTY THREE FORTY TWO
# Predicted: FIFTY THREE FORTY TWO
# Target: V E R O N A
# Predicted: V E R O N A
# Target: R O B E R T
# Predicted: R O B E R T
# Target: AUGUST TWENTY SECOND NINETEEN SIXTY NINE
# Predicted: AUGUST TWENTY SECOND NINETEEN SIXTY NINE
# Target: TEN SEVENTY ONE
# Predicted: TEN SEVENTY ONE
# Target: TWO TEN
# Predicted: TWO TEN
# Target: FOUR ONE TWO TWO SIX EIGHT FOUR FOUR SEVEN FOUR
# Predicted: FOUR ONE TWO TWO SIX EIGHT FOUR FOUR SEVEN FOUR
# Target: ONE FIVE TWO ONE SEVEN
# Predicted: ONE FIVE TWO ONE SEVEN
# Target: RUBOUT H A X X N SIX SEVEN NINE ONE
# Predicted: RUBOUT H A X X N SIX SEVEN NINE ONE
# Target: S W I S S V A L E
# Predicted: S W I S S V A L E
# Target: M C K E E S P O R T
# Predicted: M C K E E S P O R T
# Target: THREE OH EIGHT FIVE
# Predicted: THREE OH EIGHT FIVE
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: D A V I D
# Predicted: D A V I D
# Target: AREA CODE FOUR ONE TWO FOUR TWO TWO ONE TWO TWO FIVE
# Predicted: AREA CODE FOUR ONE TWO FOUR TWO TWO ONE TWO TWO FIVE
# Target: K W Z A G TWO HUNDRED AND SIXTY SIX
# Predicted: K W Z A G TWO HUNDRED SIXTY SIX
# Target: D O U G L A S
# Predicted: D O U G L A S
# Target: TWO TWO NINE THREE
# Predicted: TWO TWO NINE THREE
# Target: W A R D
# Predicted: W A R D
# Target: START
# Predicted: START
# Target: B U C K W H E A T
# Predicted: B U C K W H E A T
# Target: FEBRUARY EIGHTH NINETEEN FIFTY TWO
# Predicted: FEBRUARY EIGHTH NINETEEN FIFTY TWO
# Target: STOP
# Predicted: STOP
# Target: THREE OH ONE
# Predicted: THREE OH ONE
# Target: ONE FIVE TWO ONE THREE
# Predicted: ONE FIVE TWO ONE THREE
# Target: HELP
# Predicted: HELP
# Target: K L M U FIVE TWO SEVEN FOUR
# Predicted: K L M U FIVE TWO SEVEN FOUR
# Target: ONE NINE THREE THREE FIVE
# Predicted: ONE NINE THREE THREE FIVE
# Target: G L E N S H A W
# Predicted: G L E N S H A W
# Target: E R I C
# Predicted: E R I C
# Target: ONE FIVE TWO ONE THREE
# Predicted: ONE FIVE TWO ONE THREE
# Target: STOP
# Predicted: STOP
# Target: FOURTEEN FOURTEEN
# Predicted: FOURTEEN FOURTEEN
# Target: O A M J ONE FIVE THREE
# Predicted: O A M J ONE FIVE THREE
# Target: L I N D A
# Predicted: L I N D A
# Target: ONE FIVE ONE FOUR THREE
# Predicted: ONE FIVE ONE FOUR THREE
# Target: O L K F FIVE FORTY FIVE
# Predicted: O L K F FIVE FORTY FIVE
# Target: START
# Predicted: START
# Target: H O Y
# Predicted: H O Y
# Target: YES
# Predicted: YES
# Target: STOP
# Predicted: STOP
# Target: K E N
# Predicted: K E N
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: HELP
# Predicted: HELP
# Target: R U S K I N
# Predicted: R U S K I N
# Target: FIFTY ONE FIFTY SIX
# Predicted: FIFTY ONE FIFTY SIX
# Target: ONE FIVE TWO ONE THREE
# Predicted: ONE FIVE TWO ONE THREE
# Target: ONE FIVE TWO ZERO SIX
# Predicted: ONE FIVE TWO ZERO SIX
# Target: E L L S W O R T H
# Predicted: E L L S W O R T H
# Target: D E R E K
# Predicted: D E R E K
# Target: ONE FIVE TWO ONE OH
# Predicted: ONE FIVE TWO ONE OH
# Target: ONE FIVE TWO OH SIX
# Predicted: ONE FIVE TWO OH SIX
# Target: ENTER TWO
# Predicted: ENTER TWO
# Target: TWELVE NINE OF SIXTY
# Predicted: TWELVE NINE OF SIXTY
# Target: FIFTY SIX THIRTY TWO
# Predicted: FIFTY SIX THIRTY TWO
# Target: RUBOUT X C Z T P FOUR
# Predicted: RUBOUT X C Z T P FOUR
# Target: ONE FIVE TWO ONE SEVEN
# Predicted: ONE FIVE TWO ONE SEVEN
# Target: FOUR ONE TWO SIX EIGHT SEVEN EIGHT EIGHT SEVEN ONE
# Predicted: FOUR ONE TWO SIX EIGHT SEVEN EIGHT EIGHT SEVEN ONE
# Target: ERASE E X X S ZERO
# Predicted: ERASE E X X S ZERO
# Target: REPEAT
# Predicted: REPEAT
# Target: L O N G V I E W
# Predicted: L O N G V I E W
# Target: TWELVE TWENTY FOUR SIXTY EIGHT
# Predicted: TWELVE TWENTY FOUR SIXTY EIGHT
# Target: S K E E S
# Predicted: S K E E S
# Target: ONE FIVE TWO ONE THREE
# Predicted: ONE FIVE TWO ONE THREE
# Target: C E L L I O
# Predicted: C E L L I O
# Target: THREE FOURTEEN SIXTY SEVEN
# Predicted: THREE FOURTEEN SIXTY SEVEN
# Target: S P R I N G H O U S E
# Predicted: S P R I N G H O U S E
# Target: X G I C TWO
# Predicted: X G I C TWO
# Target: FOUR FIVE TWO EIGHT FIVE ONE EIGHT
# Predicted: FOUR FIVE TWO EIGHT FIVE ONE EIGHT
# Target: GO
# Predicted: GO
# Target: ENTER FOUR THOUSAND EIGHT HUNDRED EIGHTY THREE
# Predicted: ENTER FOUR THOUSAND EIGHT HUNDRED EIGHTY THREE
# Target: YES
# Predicted: YES
# Target: YES
# Predicted: YES
# Target: HELP
# Predicted: HELP
# Target: E R I K
# Predicted: E R I K
# Target: REPEAT
# Predicted: REPEAT
# Target: N A T H A N
# Predicted: N A T H A N
# Target: A M Y
# Predicted: A M Y
# Target: RUBOUT T G J W B SEVENTY NINE FIFTY NINE
# Predicted: RUBOUT T G J W B SEVENTY NINE FIFTY NINE
# Target: N E L S O N
# Predicted: N E L S O N
# Target: FIVE TWO ONE FOUR NINE FIVE FOUR
# Predicted: FIVE TWO ONE FOUR NINE FIVE FOUR
# Target: A R A P A H O E
# Predicted: A R A P A H O E
# Target: R A N D Y
# Predicted: R A N D Y
# Target: ENTER SIXTY SIX
# Predicted: ENTER SIXTY SIX
# Target: THREE SIX ONE ZERO ONE FIVE FIVE
# Predicted: THREE SIX ONE ZERO ONE FIVE FIVE
# Target: RUBOUT A D E U Y THREE SIXTY FOUR
# Predicted: RUBOUT A D E U Y THREE SIXTY FOUR
# Target: ERASE B M E E THREE FIVE TWO
# Predicted: ERASE B M E E THREE FIVE TWO
# Target: FOUR TWO TWO TWO OH EIGHT NINE
# Predicted: FOUR TWO TWO TWO OH EIGHT NINE
# Target: TWO SIX EIGHT FOUR SIX SEVEN EIGHT
# Predicted: TWO SIX EIGHT FOUR SIX SEVEN EIGHT
# Target: T O M
# Predicted: T O M
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: B V I Q G EIGHTY SIX
# Predicted: B V I Q G EIGHTY SIX
# Target: P I N E H U R S T
# Predicted: P I N E H U R S T
# Target: GO
# Predicted: GO
# Target: RUBOUT H F D W Q SIX TWO TWO
# Predicted: RUBOUT H F D W Q SIX TWO TWO
# Target: ENTER FOUR TWENTY ONE
# Predicted: ENTER FOUR TWENTY ONE
# Target: X H B A C FIVE THREE FOUR FOUR
# Predicted: X H B A C FIVE THREE FOUR FOUR
# Target: ONE FIVE TWO ONE SEVEN
# Predicted: ONE FIVE TWO ONE SEVEN
# Target: H O F F R I C H T E R
# Predicted: H O F F R I C H T E R
# Target: ONE FIVE TWO ONE SEVEN
# Predicted: ONE FIVE TWO ONE SEVEN
# Target: P A T T E R S O N
# Predicted: P A T T E R S O N
# Target: R Q Z H FOUR
# Predicted: R Q Z H FOUR
# Target: ERASE O J T K S THIRTY FIVE
# Predicted: ERASE O J T K S THIRTY FIVE
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: ENTER SIX OH EIGHT OH
# Predicted: ENTER SIX OH EIGHT OH
# Target: ENTER SEVENTY TWO
# Predicted: ENTER SEVENTY TWO
# Target: V E R K E THIRTY FIVE THIRTY
# Predicted: V E R K E THIRTY FIVE THIRTY
# Target: B R O N X V I L L E
# Predicted: B R O N X V I L L E
# Target: A M S J SEVEN THOUSAND ONE HUNDRED AND EIGHTY SIX
# Predicted: A M S J SEVEN THOUSAND ONE HUNDRED AND EIGHTY SIX
# Target: TWELVE TEN SIXTY NINE
# Predicted: TWELVE TEN SIXTY NINE
# Target: NO
# Predicted: NO
# Target: RUBOUT I T D K M FOUR SEVENTY ONE
# Predicted: RUBOUT I T D K M FOUR SEVENTY ONE
# Target: RUBOUT F B M J SEVEN TEN
# Predicted: RUBOUT F B M J SEVEN TEN
# Target: ONE FIVE TWO THREE TWO
# Predicted: ONE FIVE TWO THREE TWO
# Target: F E N N I M O R E
# Predicted: F E N N I M O R E
# Target: C A L I G I U R I
# Predicted: C A L I G I U R I
# Target: SIX EIGHT SEVEN FIVE EIGHT OH EIGHT
# Predicted: SIX EIGHT SEVEN FIVE EIGHT OH EIGHT
# Target: U S I Q N SEVENTY ONE
# Predicted: U S I Q N SEVENTY ONE
# Target: RUBOUT F Y N P NINETY SEVEN
# Predicted: RUBOUT F Y N P NINETY SEVEN
# Target: FORTY THREE TWENTY THREE
# Predicted: FORTY THREE TWENTY THREE
# Target: RUBOUT D Q T W X FIVE HUNDRED EIGHTY SEVEN
# Predicted: RUBOUT D Q T W X FIVE HUNDRED EIGHTY SEVEN
# Target: S A Y B R O O K H A R B O R
# Predicted: S A Y B R O O K H A R B O R
# Test set: Average loss: 0.1501, Average CER: 0.127038% Average WER: 0.1086%
# (0.0012703797746208615, 0.0010863111097577684, 0.1501303255833961)

# %%
test(model, device, batch_size, criterion, mode='val', std_output=True)
# Out:
# evaluating...
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: ERASE O T H F I FIVE ZERO
# Predicted: ERASE O T H F I I Z
# Target: YES
# Predicted: YES
# Target: EIGHT OH THREE TWO THREE FOUR FIVE NINE SEVEN TWO
# Predicted: EIGHT  THREE TWO THREE FOUR FIVE NINE SEVEN TWO
# Target: S H A R O N
# Predicted: S H A R O E N
# Target: ONE SIXTEEN FORTY EIGHT
# Predicted: ONE SIXTEEN FORTY EIGHT
# Target: FOUR ONE TWO FOUR TWO TWO NINE EIGHT TWO EIGHT
# Predicted: FOUR ONE TWO FOUR TWO TWO NINE EIGHT TWO EIGHT
# Target: RUBOUT S H K J FIVE SEVEN SIX
# Predicted: RUBOUT S H K J FIVE SEVEN SIX
# Target: SIX EIGHT THREE ONE FIVE FIVE EIGHT
# Predicted: SIX EIGHT THREE ONE FIVE  EIGHT
# Target: SEPTEMBER FIRST NINETEEN SIXTY NINE
# Predicted: SEPTEMBER FIRST NINETEEN SIXTY NINE
# Target: ONE TWO TWO TWO
# Predicted: ONE TWO TWO TWO
# Target: S P R I N G H O U S E L A N E
# Predicted: S P R I N G H W S B O A N E
# Target: ERASE N T D I C FIVE NINE ONE
# Predicted: ERASE N T D I C FIVE NINE ONE
# Target: ENTER FIVE
# Predicted: ENTER FIVE
# Target: ERASE J N R G FORTY EIGHT
# Predicted: B A J R G FORTY EIGHT
# Target: F R A N Z I N I
# Predicted: F R A N Z I N FIVE
# Target: Z EIGHT OH TWO
# Predicted: C A O TWO
# Target: N L N S ONE SEVENTY FIVE
# Predicted: M L N S ONE SEVENTY EIGHT FIVE
# Target: J S P S Z NINE SIX NINE
# Predicted: J S P S Z NINE SIX NINE
# Target: M A R K
# Predicted: M  K
# Target: S E W I C K L E Y
# Predicted: S E W Y C K L E Y
# Target: STOP
# Predicted: STOP
# Target: V L C Z TWENTY SIX
# Predicted: V L C Z TWENTY SIX
# Target: ONE OH SIX
# Predicted: ONE OH SIX
# Target: ENTER NINETY FIVE
# Predicted: ENTER NINETY FIVE
# Target: M A R N E L L
# Predicted: M A R N E L
# Target: OH SEVEN NINE TWO TWO
# Predicted:  SEVEN NINE TWO TWO
# Target: ERASE T M A Z X TWO THOUSAND FIVE HUNDRED AND FIFTY TWO
# Predicted: ERASE Q A Z X TWO THOUSAND FIVE HUNDRED AND FIFTY TWO
# Target: N E W E L L
# Predicted: N E W E L L
# Target: FIVE FIVE THREE FIVE
# Predicted: FIVE FIVE THREE FIVE
# Target: REPEAT
# Predicted: REPEAT
# Target: START
# Predicted: START
# Target: H A M P S H I R E
# Predicted: H A M P S H I R E
# Target: P O L I F R O N I
# Predicted: P O L I F R O M I
# Target: MARCH TWENTIETH NINETEEN SEVENTY
# Predicted: MARCH TWENTY NINETEEN SEVEN
# Target: S W A R T Z
# Predicted: S W A R T C
# Target: THREE TWO SEVEN
# Predicted: THREE TWO SEVEN
# Target: TWELVE TWENTY ONE FIFTY EIGHT
# Predicted: TWELVE TWENTY ONE FIFTY EIGHT
# Target: O L A C K
# Predicted: RUBOUT L A C K
# Target: F I F T H
# Predicted: F I F T H
# Target: J O H N
# Predicted: J O H N
# Target: H A N D E R S O N
# Predicted: H A N D E R O
# Target: HELP
# Predicted: HELP
# Target: R O Y
# Predicted: START O Y
# Target: ONE NINE OH OH EIGHT
# Predicted: ONE NINE OH OH EIGHT
# Target: ONE THREE SIX
# Predicted: ONE THREE SIX
# Target: ENTER FOUR FIFTY ONE
# Predicted: ENTER FOUR FIFTY ONE
# Target: RUBOUT Z Y T L FIFTY ONE
# Predicted: RUBOUT Z I T L FIFTY ONE
# Target: H O B A R T
# Predicted: H O B A R T
# Target: S T E P H E N
# Predicted: S T E P H E E N
# Target: M O R E W O O D
# Predicted: M O Y E W O O D
# Target: TWO SIX EIGHT THREE OH FIVE FOUR
# Predicted: TWO SIX EIGHT THREE OH FIVE FOUR
# Target: ERASE K J Z F M FIFTY FOUR
# Predicted: ERASE K J Z F M FIFTY FOUR
# Target: RUBOUT F X C W N FOUR
# Predicted: RUBOUT  FIVE TWO W ONEFOUR
# Target: P I T T S B U R G H
# Predicted: P I T T S B E R G H
# Target: ENTER EIGHT SEVEN
# Predicted: ENTER EIGHTY SEVEN
# Target: E A S T E N D
# Predicted: E A S T E N D
# Target: SEVEN THREE ZERO
# Predicted: SEVEN THREE ZERO
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R T H
# Target: ENTER THIRTY EIGHT SIXTY FIVE
# Predicted: ENTER THIRTIETH EIGHT SIXTY FIVE
# Target: B O X EIGHT OH SEVEN
# Predicted: B O S EIGHT OH SEVEN
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: GO
# Predicted: GO
# Target: ENTER FIVE
# Predicted: ENTER FIVE
# Target: G R O S S M A N
# Predicted: G R O S S M A N
# Target: F E D O R
# Predicted: F E D O R
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G EIGHT
# Target: X E D V SEVEN
# Predicted: X E D V SEVEN
# Target: NINTH OF SEPTEMBER NINETEEN SIXTY FOUR
# Predicted:  NINE  SEVEN NINETEEN SIXTY FOUR
# Target: ONE TWENTY
# Predicted: ONE TWENTY
# Target: W C V Y H SEVENTY SEVEN FORTY FOUR
# Predicted: W C V Y H SEVENTY SEVEN FORTY FOUR
# Target: F I L
# Predicted: F I L
# Target: GO
# Predicted: GO
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: S U N N Y V A L E
# Predicted: S  U N N Y D A L E
# Target: ERASE C B J V C THIRTY FIVE
# Predicted: ERASE C B J B C THIRTY FIVE
# Target: P U S K A R
# Predicted: P U S K A R
# Target: U M N Y H SIX
# Predicted: U M M Y EIGHT SIX
# Target: TEN ONE SIXTY EIGHT
# Predicted: SEVEN NINETY SIXTY EIGHT
# Target: ENTER NINETY EIGHT TWENTY EIGHT
# Predicted: N I D H Y EIGHT
# Target: ERASE S S W Z NINE
# Predicted: ERASE S S W Z NINE
# Target: YES
# Predicted: YES
# Target: ONE TWO ZERO
# Predicted: ONE TWO ZERO
# Target: M A T T H E W
# Predicted: M A T T A T E W
# Target: B A R R Y
# Predicted: B A R R Y
# Target: P R I N C E
# Predicted: P R I N C E
# Target: JULY TWENTY NINE NINETEEN SIXTY NINE
# Predicted: TWO NINETEEN TWENTY NINE NINETEEN SIXTY
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: ERASE W F S O L EIGHT FOUR FOUR
# Predicted: ERASE W F S O L EIGHT FOUR FOUR
# Target: GO
# Predicted: GO
# Target: FOUR FOUR OH SIX FIVE
# Predicted: FOUR FOUR OH SIX FIVE
# Target: ENTER ONE FORTY TWO
# Predicted: ENTER ONE FORTY TWO
# Target: FOUR ONE TWO SIX EIGHT SEVEN NINE FIVE TWO SIX
# Predicted: FOUR ONE TWO SIX EIGHT SEVEN NINE FIVE TWO SIX
# Target: V W A B W TWO FOURTEEN
# Predicted: B W A  W TWO FOURTEEN
# Target: ONE FIVE TWO ONE SEVEN
# Predicted: ONE FIVE TWO ONE SEVEN
# Test set: Average loss: 0.3372, Average CER: 8.996259% Average WER: 11.4974%
# (0.08996258706868343, 0.11497365207891526, 0.337231790026029)

# %%
test(model, device, batch_size, criterion, std_output=True)
# Out:
# evaluating...
# Target: ONE FIVE TWO TWO SEVEN
# Predicted: ONE FIVE TWO TWO SEVEN
# Target: ERASE K M H N I SIX OH FIVE
# Predicted: ERASE K M H N I SIX OH FIVE
# Target: NO
# Predicted: NO
# Target: ENTER EIGHT THIRTEEN
# Predicted: ENTER EIGHT FIFTEEN TWO
# Target: ENTER ONE SEVENTY SIX
# Predicted: ENTER  SEVENTY SIX
# Target: ONE FIVE TWO ONE THREE
# Predicted: ONE FIVE TWO ONE THREE
# Target: M Y E R S
# Predicted: M Y E R S
# Target: MAY SECOND NINETEEN SIXTY FIVE
# Predicted: MAY SECOND NINETEEN SIXTY FIVE
# Target: P H I N N E Y
# Predicted: P H I N N E Y
# Target: SIXTY SIX THIRTY THREE
# Predicted: SIXTY SIX THIRTY THREE
# Target: ENTER TWO NINE EIGHT ONE
# Predicted: ENTER  TWO NINE EIGHT ONE
# Target: M E L V I N
# Predicted: N E M V I N
# Target: P I T T S B U R G H
# Predicted: P I T T S B  R G H
# Target: C E D A R V I L L E
# Predicted: C E D A R V I L L E
# Target: L E V I S O N
# Predicted: M E V I S SEVEN
# Target: ONE FIVE TWO ONE SEVEN
# Predicted: ONE FIVE TWO ONE SEVEN
# Target: TWELVE THIRTY THREE
# Predicted: TWELVE THIRTY THREE
# Target: J A N E T
# Predicted: J A N E T
# Target: GO
# Predicted: GO
# Target: X K I T B TWO SIX ONE ONE
# Predicted: X K I T B TWO SIX  ONE
# Target: RUBOUT N I M N ONE
# Predicted: RUBOUT N I N N ONE
# Target: ERASE A B F N Q FIFTY SEVEN
# Predicted: ERASE  A B F N Q FIFTY SEVEN
# Target: NO
# Predicted: NO
# Target: THREE THREE ONE OH ONE EIGHT EIGHT
# Predicted: THREE THREE ONE OH ONE EIGHT EIGHT
# Target: STOP
# Predicted: STOP
# Target: ENTER SEVEN
# Predicted: ENTER SEVEN
# Target: TWO TWO SIX
# Predicted: TWO TWO SIX
# Target: OCTOBER TWENTY FOUR NINETEEN SEVENTY
# Predicted: FIVE  TWENTY FOUR NINETEEN SEVENTY
# Target: X N K U EIGHT
# Predicted: X N K EIGHT
# Target: W O O D
# Predicted: W  O O D
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: THREE ZERO TWO ONE
# Predicted: THREE ZERO TWO ONE
# Target: RUBOUT U B U T R SIX
# Predicted: RUBOUT U B EU T I SIX
# Target: R O C H E S T E R
# Predicted: R O C H E S T E R
# Target: M O R E W O O D
# Predicted: M O R E W O O D
# Target: ONE THREE SEVEN
# Predicted: ONE THREE SEVEN
# Target: RUBOUT G M E F THREE NINE
# Predicted: RUBOUT G M E ENTER THREE NINE
# Target: TWELVE TWENTY NINE FIFTY NINE
# Predicted: TWELVE TWENTY NINE FIFTY NINE
# Target: ENTER FOUR FIVE EIGHT TWO ONE
# Predicted: ENTER FOUR FIVE EIGHT TWO ONE
# Target: E R I C
# Predicted: E R I
# Target: J P E G FOUR
# Predicted: J P E G FOUR R
# Target: NINETEEN
# Predicted: REPEAT
# Target: FOUR ONE TWO TWO SIX EIGHT FOUR ONE FOUR TWO
# Predicted: FOUR ONE TWO SIX EIGHT FOUR ONE FOUR TWO
# Target: ONE FIVE TWO THREE SIX
# Predicted: ONE FIVE TWO THREE SIX
# Target: W Y A T U SEVENTY SEVEN SEVENTY SEVEN
# Predicted: W Y A T U SEVENTY SEVEN SEVENTY SEVEN
# Target: ONE FIVE TWO TWO FOUR
# Predicted: ONE FIVE TWO TWO FOUR
# Target: ONE FOUR SIX ONE EIGHT
# Predicted: ONE FOUR SIX ONE EIGHT
# Target: M I C H A E L
# Predicted: M I A H A EL
# Target: OH TWO ONE SEVEN THREE
# Predicted: OH TWO ONE SEVEN THREE
# Target: M C K E E S R O C K S
# Predicted: N C K E E S R O OC K S
# Target: ENTER FIVE SIX EIGHT
# Predicted: ENTER FIVE SIX EIGHT
# Target: ENTER SEVEN ONE FIVE FOUR
# Predicted: ENTER SEVEN ONE FIVE FOUR
# Target: ENTER ONE OH FOUR
# Predicted: ENTER ONE OH FOUR
# Target: ERASE E D Z E FIFTY SIX
# Predicted: ERASE U D Z EIGHTY FIFTY SIX
# Target: ENTER TWO EIGHTEEN
# Predicted: ENTER TWO EIGHT
# Target: P O W E L L
# Predicted: P O W E L L
# Target: Y A N A S A K
# Predicted: Y A N A S A K
# Target: TWO FORTY
# Predicted: TWO FORTY
# Target: G I N S B E R G
# Predicted: G I N S B E R J
# Target: B I R C H W O O D
# Predicted: B R R C H W O O D
# Target: ERASE U D B E FIVE
# Predicted: ERASE U D B E FIVE
# Target: NO
# Predicted: NO
# Target: NOVEMBER NINTH SIXTY FIVE
# Predicted: ENTER NINETEEN SIXTY FIVE
# Target: L K K N THIRTY EIGHT
# Predicted: L K K M THIRTY EIGHT
# Target: W I L L E T T
# Predicted: W Y L L E T TWO
# Target: ENTER THIRTY
# Predicted: ENTER THIRTY
# Target: A L A N
# Predicted: A L A N
# Target: SIX EIGHT THREE SIX ZERO TWO SEVEN
# Predicted: SIX EIGHT THREE SIXTY OH TWO SEVEN
# Target: K A U F M A N
# Predicted: K A U F M A N
# Target: H O U S E R
# Predicted: H O U S E R
# Target: T R T F I SEVEN
# Predicted: T R T F Y SEVEN
# Target: FOUR TWO ONE EIGHT EIGHT SIX OH
# Predicted: FOUR TWO ONE EIGHT EIGHT SIX
# Target: L E X I N G T O N
# Predicted: L E X I N G T O N
# Target: I V A N
# Predicted: FIVE V A N
# Target: M A R G A R E T M O R R I S O N
# Predicted: M A R G A I T M O R R I S O N
# Target: ELEVEN TWENTY SEVEN FIFTY SEVEN
# Predicted:   TWENTY SEVEN FIFTY SEVEN
# Target: R H N G A FIFTY FOUR EIGHTY THREE
# Predicted: R H AND G EIGHT FIFTY FORTY  THREE
# Target: P L E A S A N T H I L L S
# Predicted: P L E A S A N T H I M L A
# Target: EIGHT EIGHT FOUR THREE SIX FOUR EIGHT
# Predicted: EIGHT FOUR THREE SIX FOUR EIGHT
# Target: ENTER NINE ONE SIX NINE
# Predicted: ENTER NINE ONE SIX NINE
# Target: MARCH SEVEN NINETEEN SIXTY SEVEN
# Predicted: MARCH  NINETEEN SIX SEVEN
# Target: B A O Z FIVE THREE
# Predicted: B A O Z FIVE THREE
# Target: G F T U ONE THREE THREE TWO
# Predicted: G F T U ONE THREE THREE TWO
# Target: S A N D L E R
# Predicted: S A M D L E R
# Target: ONE FIVE ONE THREE SIX
# Predicted: ONE FIVE ONE THREE SIX
# Target: W I L L O W B E N D
# Predicted: W I L L O W B E N D
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: ENTER TWENTY ONE
# Predicted: ENTER TWENTY ONE
# Target: TWO SIX EIGHT FOUR SIX NINE FOUR
# Predicted: TWO SIX EIGHT FOUR SIX NINE FOUR
# Target: V A N E S S A
# Predicted: V A M E S SIX A
# Target: ONE FIFTY
# Predicted: ONE FIFTY
# Target: JUNE EIGHTEENTH NINETEEN SIXTY EIGHT
# Predicted: JUNE  NINETEEN  SIXTY EIGHT
# Target: RUBOUT E Y F C X FOUR
# Predicted: RUBOUT E Y S C S FOUR
# Target: ERASE X A G N A SIX THIRTY FIVE
# Predicted: ERASE X A G N A SIX THIRTY FIVE
# Target: C E N T R E
# Predicted: C E N T R E
# Target: A B V J NINETY FOUR
# Predicted: E B V J NINETY FOUR
# Target: ERASE F O X K EIGHT
# Predicted: ERASE F O X K EIGHT
# Target: S Y F C D NINE SIX OH ONE SEVEN
# Predicted: S Y S Z D NINE SIX OH ONE SEVEN
# Target: A SEVEN
# Predicted: A SEVEN
# Target: C I N D Y
# Predicted: C I E D Y
# Target: B R E N T W O O D
# Predicted: B R E N T W O O D
# Target: S P E E R
# Predicted: S P E E R
# Target: RUBOUT G R A G EIGHTY FIVE
# Predicted: RUBOUT G R H G EIGHTY FIVE
# Target: ONE FIVE TWO THREE TWO
# Predicted: ONE FIVE TWO THREE TWO
# Target: EIGHT SIX TWO OH THREE EIGHT SEVEN
# Predicted: EIGHT SIX TWO OH THREE EIGHT SEVEN
# Target: RUBOUT N S V H T SIX FORTY NINE
# Predicted: RUBOUT N S B H T SIX FORTY NINE
# Target: FIFTY TWO NINETEEN
# Predicted: FIFTY TWO NINETY
# Target: ENTER NINE TWO EIGHT
# Predicted: ENTER NINE TWO EIGHT
# Target: SEVEN ONE SIX TWO FOUR FOUR SIX SEVEN ONE FOUR
# Predicted: SEVEN ONE SIX TWO FOUR FOUR SIX SEVEN ONE FOUR
# Target: D A J N H NINETY SIX
# Predicted: D A J N H NINETY SIX
# Target: J O H N
# Predicted: J OH EIGHT TEN
# Target: FIVE TWENTY SEVEN SIXTY SIX
# Predicted: FIVE TWENTY SEVEN SIXTY SIX
# Target: YES
# Predicted: YES
# Target: D A V I D
# Predicted: D A D I A D
# Target: ERASE C Q Q F SEVEN
# Predicted: ERASE  C Q Q ENTER SEVEN
# Target: RUBOUT C B W X V FOUR
# Predicted: RUBOUT  B W X V FOUR
# Target: RUBOUT V Z J H P SEVEN THIRTY SIX
# Predicted: RUBOUT  B G J H P SEVEN THIRTY SIX
# Target: ENTER EIGHT
# Predicted: ENTER EIGHT
# Target: J E F F R E Y
# Predicted: J E F F R E Y
# Target: SIX EIGHT THREE THREE OH SEVEN FIVE
# Predicted: SIX EIGHT THREE THREE OH SEVEN FIVE
# Target: SIX FIVE FIVE EIGHT SEVEN FOUR ZERO
# Predicted: SIX FIVE FIVE EIGHT SEVEN  Z
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: REPEAT
# Predicted: REPEAT
# Target: P A T T E R S O N
# Predicted: P A T T E R S O N
# Target: ENTER EIGHT NINETY SEVEN
# Predicted: ENTER EIGHT NINE SEVEN
# Target: JANUARY SEVENTH NINETEEN SIXTY SEVEN
# Predicted: ENTER SEVEN NINETEEN SIXTY SEVEN
# Target: TEN TWENTY SEVEN SIXTY TWO
# Predicted: SEVEN TWENTY SEVEN SIXTY TWO
# Target: P I T T S B U R G H
# Predicted: P I T T S B U R G H
# Target: ERASE P Q Y V T FIVE NINETY EIGHT
# Predicted: ERASE P Q Y V T FIVE NINETY EIGHT
# Target: ONE FIVE TWO ONE THREE
# Predicted: ONE FIVE TWO ONE THREE
# Test set: Average loss: 0.2776, Average CER: 7.974979% Average WER: 10.8077%
# (0.0797497860906476, 0.10807653884576959, 0.27760335471895004)
